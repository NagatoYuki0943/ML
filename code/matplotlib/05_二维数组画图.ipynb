# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arr1 = np.random.randint(1, 10, 100)
arr2 = np.random.randint(10, 100, 100)
arr3 = np.random.randint(100, 1000, 100)

# %% [markdown]
# ## plt和sns使用二维数据画图是取每1列画1条线

# %% [markdown]
# ## 3,100

# %%
arr11 = np.stack([arr1, arr2, arr3], axis=0)
arr11
# Out:
# array([[  9,   8,   7,   6,   7,   8,   6,   4,   2,   7,   8,   1,   3,
#           4,   3,   1,   4,   8,   2,   6,   5,   4,   4,   3,   7,   1,
#           9,   3,   5,   3,   4,   6,   4,   7,   5,   4,   4,   9,   9,
#           8,   7,   9,   6,   2,   6,   8,   4,   4,   5,   8,   1,   3,
#           8,   7,   3,   2,   7,   7,   4,   8,   1,   7,   8,   1,   4,
#           4,   4,   7,   7,   3,   1,   1,   4,   4,   4,   4,   6,   3,
#           3,   2,   1,   8,   8,   2,   6,   3,   1,   6,   2,   6,   4,
#           9,   7,   9,   5,   7,   5,   5,   1,   6],
#        [ 93,  24,  36,  74,  18,  53,  76,  58,  33,  20,  55,  61,  68,
#          32,  74,  99,  11,  59,  64,  87,  12,  72,  75,  54,  79,  65,
#          98,  39,  99,  99,  93,  23,  80,  77,  98,  36,  83,  19,  57,
#          24,  10,  59,  53,  29,  64,  37,  53,  76,  97,  47,  68,  52,
#          15,  88,  41,  47,  83,  30,  33,  18,  55,  50,  61,  65,  68,
#          14,  53,  80,  16,  77,  30,  90,  48,  11,  31,  49,  89,  25,
#          21,  50,  52,  10,  94,  72,  95,  52,  92,  83,  83,  40,  44,
#          73,  18,  13,  71,  41,  75,  24,  66,  61],
#        [963, 749, 821, 672, 362, 690, 482, 400, 951, 485, 226, 572, 752,
#         976, 934, 943, 281, 902, 210, 426, 431, 400, 384, 185, 543, 626,
#         678, 599, 516, 829, 888, 369, 272, 954, 815, 583, 230, 327, 423,
#         605, 927, 891, 339, 313, 367, 860, 752, 805, 902, 947, 871, 549,
#         529, 967, 726, 220, 598, 845, 739, 547, 908, 157, 747, 153, 181,
#         716, 796, 602, 910, 774, 586, 367, 344, 915, 838, 808, 153, 698,
#         599, 201, 729, 713, 642, 537, 717, 379, 828, 662, 536, 502, 551,
#         702, 731, 846, 982, 754, 198, 111, 765, 337]])

# %% [markdown]
# ## 100,3

# %%
arr22 = np.stack([arr1, arr2, arr3], axis=1)
arr22
# Out:
# array([[  9,  93, 963],
#        [  8,  24, 749],
#        [  7,  36, 821],
#        [  6,  74, 672],
#        [  7,  18, 362],
#        [  8,  53, 690],
#        [  6,  76, 482],
#        [  4,  58, 400],
#        [  2,  33, 951],
#        [  7,  20, 485],
#        [  8,  55, 226],
#        [  1,  61, 572],
#        [  3,  68, 752],
#        [  4,  32, 976],
#        [  3,  74, 934],
#        [  1,  99, 943],
#        [  4,  11, 281],
#        [  8,  59, 902],
#        [  2,  64, 210],
#        [  6,  87, 426],
#        [  5,  12, 431],
#        [  4,  72, 400],
#        [  4,  75, 384],
#        [  3,  54, 185],
#        [  7,  79, 543],
#        [  1,  65, 626],
#        [  9,  98, 678],
#        [  3,  39, 599],
#        [  5,  99, 516],
#        [  3,  99, 829],
#        [  4,  93, 888],
#        [  6,  23, 369],
#        [  4,  80, 272],
#        [  7,  77, 954],
#        [  5,  98, 815],
#        [  4,  36, 583],
#        [  4,  83, 230],
#        [  9,  19, 327],
#        [  9,  57, 423],
#        [  8,  24, 605],
#        [  7,  10, 927],
#        [  9,  59, 891],
#        [  6,  53, 339],
#        [  2,  29, 313],
#        [  6,  64, 367],
#        [  8,  37, 860],
#        [  4,  53, 752],
#        [  4,  76, 805],
#        [  5,  97, 902],
#        [  8,  47, 947],
#        [  1,  68, 871],
#        [  3,  52, 549],
#        [  8,  15, 529],
#        [  7,  88, 967],
#        [  3,  41, 726],
#        [  2,  47, 220],
#        [  7,  83, 598],
#        [  7,  30, 845],
#        [  4,  33, 739],
#        [  8,  18, 547],
#        [  1,  55, 908],
#        [  7,  50, 157],
#        [  8,  61, 747],
#        [  1,  65, 153],
#        [  4,  68, 181],
#        [  4,  14, 716],
#        [  4,  53, 796],
#        [  7,  80, 602],
#        [  7,  16, 910],
#        [  3,  77, 774],
#        [  1,  30, 586],
#        [  1,  90, 367],
#        [  4,  48, 344],
#        [  4,  11, 915],
#        [  4,  31, 838],
#        [  4,  49, 808],
#        [  6,  89, 153],
#        [  3,  25, 698],
#        [  3,  21, 599],
#        [  2,  50, 201],
#        [  1,  52, 729],
#        [  8,  10, 713],
#        [  8,  94, 642],
#        [  2,  72, 537],
#        [  6,  95, 717],
#        [  3,  52, 379],
#        [  1,  92, 828],
#        [  6,  83, 662],
#        [  2,  83, 536],
#        [  6,  40, 502],
#        [  4,  44, 551],
#        [  9,  73, 702],
#        [  7,  18, 731],
#        [  9,  13, 846],
#        [  5,  71, 982],
#        [  7,  41, 754],
#        [  5,  75, 198],
#        [  5,  24, 111],
#        [  1,  66, 765],
#        [  6,  61, 337]])

# %% [markdown]
# ## (3, 100)画出100条线 plt和sns相同

# %%
arr11.shape
# Out:
# (3, 100)

# %%
# 画出了100条线
plt.plot(arr11)
# Out:
# [<matplotlib.lines.Line2D at 0x2cfffc8cdf0>,
#  <matplotlib.lines.Line2D at 0x2cfffc8ce50>,
#  <matplotlib.lines.Line2D at 0x2cfffc8ce80>,
#  <matplotlib.lines.Line2D at 0x2cfffc8cf70>,
#  <matplotlib.lines.Line2D at 0x2cfffc7ed90>,
#  <matplotlib.lines.Line2D at 0x2cfffc5af70>,
#  <matplotlib.lines.Line2D at 0x2cfffca5160>,
#  <matplotlib.lines.Line2D at 0x2cfffca5250>,
#  <matplotlib.lines.Line2D at 0x2cfffca5340>,
#  <matplotlib.lines.Line2D at 0x2cfffca5430>,
#  <matplotlib.lines.Line2D at 0x2cfffc8ce20>,
#  <matplotlib.lines.Line2D at 0x2cfffca5520>,
#  <matplotlib.lines.Line2D at 0x2cfffca5610>,
#  <matplotlib.lines.Line2D at 0x2cfffca57c0>,
#  <matplotlib.lines.Line2D at 0x2cfffca58b0>,
#  <matplotlib.lines.Line2D at 0x2cfffca59a0>,
#  <matplotlib.lines.Line2D at 0x2cfffca5a90>,
#  <matplotlib.lines.Line2D at 0x2cfffca5b80>,
#  <matplotlib.lines.Line2D at 0x2cfffca5c70>,
#  <matplotlib.lines.Line2D at 0x2cfffca5d60>,
#  <matplotlib.lines.Line2D at 0x2cfffca5e50>,
#  <matplotlib.lines.Line2D at 0x2cfffca5f40>,
#  <matplotlib.lines.Line2D at 0x2cfffcac070>,
#  <matplotlib.lines.Line2D at 0x2cfffcac160>,
#  <matplotlib.lines.Line2D at 0x2cfffcac250>,
#  <matplotlib.lines.Line2D at 0x2cfffcac340>,
#  <matplotlib.lines.Line2D at 0x2cfffcac430>,
#  <matplotlib.lines.Line2D at 0x2cfffcac520>,
#  <matplotlib.lines.Line2D at 0x2cfffcac610>,
#  <matplotlib.lines.Line2D at 0x2cfffcac700>,
#  <matplotlib.lines.Line2D at 0x2cfffcac7f0>,
#  <matplotlib.lines.Line2D at 0x2cfffcac8e0>,
#  <matplotlib.lines.Line2D at 0x2cfffcac9d0>,
#  <matplotlib.lines.Line2D at 0x2cfffcacac0>,
#  <matplotlib.lines.Line2D at 0x2cfffcacbb0>,
#  <matplotlib.lines.Line2D at 0x2cfffcacca0>,
#  <matplotlib.lines.Line2D at 0x2cfffcacd90>,
#  <matplotlib.lines.Line2D at 0x2cfffcace80>,
#  <matplotlib.lines.Line2D at 0x2cfffcacf70>,
#  <matplotlib.lines.Line2D at 0x2cfffc6f5b0>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5100>,
#  <matplotlib.lines.Line2D at 0x2cfffcb51f0>,
#  <matplotlib.lines.Line2D at 0x2cfffcb52e0>,
#  <matplotlib.lines.Line2D at 0x2cfffcb53d0>,
#  <matplotlib.lines.Line2D at 0x2cfffcb54c0>,
#  <matplotlib.lines.Line2D at 0x2cfffcb55b0>,
#  <matplotlib.lines.Line2D at 0x2cfffcb56a0>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5790>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5880>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5970>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5a60>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5b50>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5c40>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5d30>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5e20>,
#  <matplotlib.lines.Line2D at 0x2cfffcb5f10>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe040>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe130>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe220>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe310>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe400>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe4f0>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe5e0>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe6d0>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe7c0>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe8b0>,
#  <matplotlib.lines.Line2D at 0x2cfffcbe9a0>,
#  <matplotlib.lines.Line2D at 0x2cfffcbea90>,
#  <matplotlib.lines.Line2D at 0x2cfffcbeb80>,
#  <matplotlib.lines.Line2D at 0x2cfffcbec70>,
#  <matplotlib.lines.Line2D at 0x2cfffcbed60>,
#  <matplotlib.lines.Line2D at 0x2cfffcbee50>,
#  <matplotlib.lines.Line2D at 0x2cfffcbef40>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7070>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7160>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7250>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7340>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7430>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7520>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7610>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7700>,
#  <matplotlib.lines.Line2D at 0x2cfffcc77f0>,
#  <matplotlib.lines.Line2D at 0x2cfffcc78e0>,
#  <matplotlib.lines.Line2D at 0x2cfffcc79d0>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7ac0>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7bb0>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7ca0>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7d90>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7e80>,
#  <matplotlib.lines.Line2D at 0x2cfffcc7f70>,
#  <matplotlib.lines.Line2D at 0x2cfffccf0a0>,
#  <matplotlib.lines.Line2D at 0x2cfffccf190>,
#  <matplotlib.lines.Line2D at 0x2cfffccf280>,
#  <matplotlib.lines.Line2D at 0x2cfffccf370>,
#  <matplotlib.lines.Line2D at 0x2cfffccf460>,
#  <matplotlib.lines.Line2D at 0x2cfffccf550>,
#  <matplotlib.lines.Line2D at 0x2cfffccf640>,
#  <matplotlib.lines.Line2D at 0x2cfffccf730>,
#  <matplotlib.lines.Line2D at 0x2cfffccf820>,
#  <matplotlib.lines.Line2D at 0x2cfffccf910>]

# %%
sns.kdeplot(arr11)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## (100, 3)画出3条线 plt和sns相同

# %%
arr22.shape
# Out:
# (100, 3)

# %%
# 画出了3条线
plt.plot(arr22)
# Out:
# [<matplotlib.lines.Line2D at 0x2cf9025e0a0>,
#  <matplotlib.lines.Line2D at 0x2cf9025e100>,
#  <matplotlib.lines.Line2D at 0x2cf9025e130>]

# %%
sns.kdeplot(arr22)
# Out:
# <Axes: ylabel='Density'>
