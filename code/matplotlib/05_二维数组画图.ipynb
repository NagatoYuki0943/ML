# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arr1 = np.random.randint(1, 10, 100)
arr2 = np.random.randint(10, 100, 100)
arr3 = np.random.randint(100, 1000, 100)

# %% [markdown]
# ## plt和sns使用二维数据画图是取每1列画1条线

# %% [markdown]
# ## 3,100

# %%
arr11 = np.stack([arr1, arr2, arr3], axis=0)
arr11
# Out:
# array([[  9,   1,   3,   7,   6,   9,   9,   9,   6,   5,   5,   2,   3,
#           3,   7,   8,   6,   8,   4,   5,   6,   7,   9,   6,   3,   6,
#           7,   2,   6,   4,   1,   5,   2,   5,   4,   7,   4,   9,   9,
#           8,   1,   8,   1,   9,   6,   3,   3,   6,   2,   5,   9,   9,
#           6,   1,   7,   3,   9,   7,   3,   3,   8,   7,   8,   1,   8,
#           2,   9,   3,   9,   2,   3,   4,   3,   8,   2,   7,   6,   1,
#           5,   5,   9,   2,   3,   3,   9,   8,   3,   1,   5,   1,   2,
#           7,   7,   4,   4,   1,   3,   9,   2,   7],
#        [ 14,  78,  38,  92,  50,  57,  55,  67,  75,  30,  87,  54,  78,
#          68,  30,  68,  52,  86,  74,  53,  51,  99,  48,  32,  62,  24,
#          10,  99,  96,  87,  41,  61,  99,  29,  11,  19,  51,  39,  47,
#          65,  95,  29,  85,  78,  79,  59,  33,  98,  28,  18,  38,  12,
#          19,  60,  68,  21,  75,  15,  48,  69,  53,  27,  34,  96,  54,
# ...

# %% [markdown]
# ## 100,3

# %%
arr22 = np.stack([arr1, arr2, arr3], axis=1)
arr22
# Out:
# array([[  9,  14, 143],
#        [  1,  78, 246],
#        [  3,  38, 934],
#        [  7,  92, 665],
#        [  6,  50, 972],
#        [  9,  57, 664],
#        [  9,  55, 110],
#        [  9,  67, 703],
#        [  6,  75, 678],
#        [  5,  30, 643],
#        [  5,  87, 820],
#        [  2,  54, 343],
#        [  3,  78, 139],
#        [  3,  68, 765],
#        [  7,  30, 758],
#        [  8,  68, 749],
#        [  6,  52, 842],
#        [  8,  86, 655],
#        [  4,  74, 776],
#        [  5,  53, 706],
#        [  6,  51, 271],
#        [  7,  99, 146],
#        [  9,  48, 145],
#        [  6,  32, 300],
#        [  3,  62, 929],
#        [  6,  24, 308],
#        [  7,  10, 169],
#        [  2,  99, 813],
#        [  6,  96, 609],
#        [  4,  87, 709],
#        [  1,  41, 183],
#        [  5,  61, 509],
#        [  2,  99, 398],
#        [  5,  29, 729],
#        [  4,  11, 692],
#        [  7,  19, 872],
#        [  4,  51, 135],
#        [  9,  39, 188],
# ...

# %% [markdown]
# ## (3, 100)画出100条线 plt和sns相同

# %%
arr11.shape
# Out:
# (3, 100)

# %%
# 画出了100条线
plt.plot(arr11)

# %%
sns.kdeplot(arr11)
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# ## (100, 3)画出3条线 plt和sns相同

# %%
arr22.shape
# Out:
# (100, 3)

# %%
# 画出了3条线
plt.plot(arr22)

# %%
sns.kdeplot(arr22)
# Out:
# <AxesSubplot: ylabel='Density'>
