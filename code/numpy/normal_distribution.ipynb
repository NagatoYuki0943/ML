# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # σ的作用
#
# - 横轴区间（μ-σ,μ+σ）内的面积为68.268949%
# - 横轴区间（μ-2σ,μ+2σ）内的面积为95.449974%
# - 横轴区间（μ-3σ,μ+3σ）内的面积为99.730020%

# %%
x = np.random.normal(loc=0, scale=1, size=1_000_000)

# %%
plt.hist(x, bins=1000)
plt.show()

# %%
x1 = x[np.bitwise_and(x>(-1), x<1)]
print(x1.shape)
plt.hist(x1, bins=1000)
plt.show()
# Out:
# (682588,)

# %%
x1 = x[np.bitwise_and(x>(-1.5), x<1.5)]
print(x1.shape)
plt.hist(x1, bins=1000)
plt.show()
# Out:
# (866692,)

# %%
x1 = x[np.bitwise_and(x>(-2), x<2)]
print(x1.shape)
plt.hist(x1, bins=1000)
plt.show()
# Out:
# (954779,)

# %%
x1 = x[np.bitwise_and(x>(-2.5), x<2.5)]
print(x1.shape)
plt.hist(x1, bins=1000)
plt.show()
# Out:
# (987789,)

# %%
x1 = x[np.bitwise_and(x>(-3), x<3)]
print(x1.shape)
plt.hist(x1, bins=1000)
plt.show()
# Out:
# (997403,)
