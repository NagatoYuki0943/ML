# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 基本数据操作

# %%
# 读取文件
data = pd.read_csv("../data/stock_day.csv")
# 删除一些列，让数据更简单些，再去做后面的操作
data = data.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"], axis=1)
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58
# ...              ...
# 2015-03-06      6.16
# 2015-03-05      3.19
# 2015-03-04      2.30
# 2015-03-03      4.76
# 2015-03-02      3.30
#
# [643 rows x 8 columns]

# %% [markdown]
# ## 索引操作

# %% [markdown]
# ### 直接使用行列索引(先列后行)

# %%
# 获取'2018-02-27'这天的'close'的结果
# 直接使用行列索引名字的方式（先列后行）
data['open']['2018-02-27']
# Out:
# 23.53

# %%
# 获取多列
data[['open', 'close']]
# Out:
#              open  close
# 2018-02-27  23.53  24.16
# 2018-02-26  22.80  23.53
# 2018-02-23  22.88  22.82
# 2018-02-22  22.25  22.28
# 2018-02-14  21.49  21.92
# ...           ...    ...
# 2015-03-06  13.17  14.28
# 2015-03-05  12.88  13.16
# 2015-03-04  12.80  12.90
# 2015-03-03  12.52  12.70
# 2015-03-02  12.25  12.52
#
# [643 rows x 2 columns]

# %%
#(先行后列不支)
data['2018-02-27']['open']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2018-02-27'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 #(先行后列不支)
# ----> 2 data['2018-02-27']['open']
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: '2018-02-27'

# %%
# 这样切片支持,不支持一次性多维切片 里面是行
data[:5]
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-22  21.446  21.909  23.137  35397.58  39904.78  60149.60      0.90
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58

# %%
# 这样不行, 后面的 2 是在是5行的前2行
data[:5][:2]
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53

# %%
# 错误  不支持切片
data[:1, :2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, 1, None), slice(None, 2, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 错误  不支持切片
# ----> 2 data[:1, :2]
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\core\indexes\base.py:3810, in Index.get_loc(self, key, method, tolerance)
#    3805         raise KeyError(key) from err
#    3806     except TypeError:
#    3807         # If we have a listlike key, _check_indexing_error will raise
#    3808         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809         #  the TypeError.
# -> 3810         self._check_indexing_error(key)
#    3811         raise
#    3813 # GH#42269
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\core\indexes\base.py:5968, in Index._check_indexing_error(self, key)
#    5964 def _check_indexing_error(self, key):
#    5965     if not is_scalar(key):
#    5966         # if key is not a scalar, directly raise an error (the code below
#    5967         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5968         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, 1, None), slice(None, 2, None))

# %% [markdown]
# ### 结合loc或者iloc使用索引

# %% [markdown]
# #### df.loc(行, 列) 通过标签索引行数据

# %%
# 使用loc:只能指定行列索引的名字
data.loc['2018-02-27':'2018-02-22', 'open']
# Out:
# 2018-02-27    23.53
# 2018-02-26    22.80
# 2018-02-23    22.88
# 2018-02-22    22.25
# Name: open, dtype: float64

# %% [markdown]
# #### df.iloc(行, 列) 通过位置获取行数据

# %%
# 获取前3天数据,前5列的结果
data.iloc[:3, :5]
# Out:
#              open   high  close    low    volume
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01

# %% [markdown]
# ### 使用ix组合索引

# %%
# 使用ix进行下表和名称组合做引
data.ix[0:4, ['open', 'close', 'high', 'low']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 使用ix进行下表和名称组合做引
# ----> 2 data.ix[0:4, ['open', 'close', 'high', 'low']]
#
# File f:\Miniconda3\envs\pytorch\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
# 推荐使用loc和iloc来获取的方式
# loc中填的是index和columns名字
data.loc[data.index[0:4], ['open', 'close', 'high', 'low']]
# Out:
#              open  close   high    low
# 2018-02-27  23.53  24.16  25.88  23.53
# 2018-02-26  22.80  23.53  23.78  22.80
# 2018-02-23  22.88  22.82  23.37  22.71
# 2018-02-22  22.25  22.28  22.76  22.02

# %%
data.columns.get_indexer(['open', 'close', 'high', 'low'])
# Out:
# array([0, 2, 1, 3], dtype=int64)

# %%
# iloc中填的是切片数字
data.iloc[0:4, data.columns.get_indexer(['open', 'close', 'high', 'low'])]
# Out:
#              open  close   high    low
# 2018-02-27  23.53  24.16  25.88  23.53
# 2018-02-26  22.80  23.53  23.78  22.80
# 2018-02-23  22.88  22.82  23.37  22.71
# 2018-02-22  22.25  22.28  22.76  22.02

# %% [markdown]
# ## 赋值操作

# %%
# 中括号
data['close'] = 1
data.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88      1  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78      1  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37      1  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76      1  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99      1  21.48  23331.04          0.44      2.05
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-22  21.446  21.909  23.137  35397.58  39904.78  60149.60      0.90
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58

# %%
# 点赋值
data.close = 2
data.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88      2  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78      2  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37      2  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76      2  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99      2  21.48  23331.04          0.44      2.05
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-22  21.446  21.909  23.137  35397.58  39904.78  60149.60      0.90
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58

# %% [markdown]
# ## 排序

# %% [markdown]
# ### DataFrame排序

# %% [markdown]
# #### df.sort_values(by=, ascending=)

# %%
# 按照开盘价大小进行排序 , 使用ascending指定按照大小排序
data.sort_values(by="open", ascending=True).head()
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2015-03-02  12.25  12.67      2  12.20   96291.73          0.32      2.62
# 2015-09-02  12.30  14.11      2  12.30   70201.74         -1.10     -8.17
# 2015-03-03  12.52  13.06      2  12.52  139071.61          0.18      1.44
# 2015-03-04  12.80  12.92      2  12.61   67075.44          0.20      1.57
# 2015-03-05  12.88  13.45      2  12.87   93180.39          0.26      2.02
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# 2015-03-02  12.520  12.520  12.520   96291.73   96291.73   96291.73      3.30
# 2015-09-02  14.440  16.591  18.360   96977.99   98537.72  104567.25      2.40
# 2015-03-03  12.610  12.610  12.610  117681.67  117681.67  117681.67      4.76
# 2015-03-04  12.707  12.707  12.707  100812.93  100812.93  100812.93      2.30
# 2015-03-05  12.820  12.820  12.820   98904.79   98904.79   98904.79      3.19

# %%
# 按照多个键进行排序
data.sort_values(by=['open', 'high']).head()
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2015-03-02  12.25  12.67      2  12.20   96291.73          0.32      2.62
# 2015-09-02  12.30  14.11      2  12.30   70201.74         -1.10     -8.17
# 2015-03-03  12.52  13.06      2  12.52  139071.61          0.18      1.44
# 2015-03-04  12.80  12.92      2  12.61   67075.44          0.20      1.57
# 2015-03-05  12.88  13.45      2  12.87   93180.39          0.26      2.02
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# 2015-03-02  12.520  12.520  12.520   96291.73   96291.73   96291.73      3.30
# 2015-09-02  14.440  16.591  18.360   96977.99   98537.72  104567.25      2.40
# 2015-03-03  12.610  12.610  12.610  117681.67  117681.67  117681.67      4.76
# 2015-03-04  12.707  12.707  12.707  100812.93  100812.93  100812.93      2.30
# 2015-03-05  12.820  12.820  12.820   98904.79   98904.79   98904.79      3.19

# %% [markdown]
# #### df.sort_index 索引排序

# %%
data.sort_index().head()
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2015-03-02  12.25  12.67      2  12.20   96291.73          0.32      2.62
# 2015-03-03  12.52  13.06      2  12.52  139071.61          0.18      1.44
# 2015-03-04  12.80  12.92      2  12.61   67075.44          0.20      1.57
# 2015-03-05  12.88  13.45      2  12.87   93180.39          0.26      2.02
# 2015-03-06  13.17  14.48      2  13.13  179831.72          1.12      8.51
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# 2015-03-02  12.520  12.520  12.520   96291.73   96291.73   96291.73      3.30
# 2015-03-03  12.610  12.610  12.610  117681.67  117681.67  117681.67      4.76
# 2015-03-04  12.707  12.707  12.707  100812.93  100812.93  100812.93      2.30
# 2015-03-05  12.820  12.820  12.820   98904.79   98904.79   98904.79      3.19
# 2015-03-06  13.112  13.112  13.112  115090.18  115090.18  115090.18      6.16

# %% [markdown]
# ### Series排序

# %% [markdown]
# #### series.sort_values(ascending=True)

# %%
# 取一列
data['high']
# 日期代表索引
# Out:
# 2018-02-27    25.88
# 2018-02-26    23.78
# 2018-02-23    23.37
# 2018-02-22    22.76
# 2018-02-14    21.99
#               ...
# 2015-03-06    14.48
# 2015-03-05    13.45
# 2015-03-04    12.92
# 2015-03-03    13.06
# 2015-03-02    12.67
# Name: high, Length: 643, dtype: float64

# %%
# series排序时，只有一列，不需要参数
data['high'].sort_values(ascending=True).head()
# Out:
# 2015-03-02    12.67
# 2015-03-04    12.92
# 2015-03-03    13.06
# 2015-09-07    13.38
# 2015-03-05    13.45
# Name: high, dtype: float64

# %% [markdown]
# #### series.sort_index() 排序

# %%
# 对索引进行排序
data['high'].sort_index().head()
# Out:
# 2015-03-02    12.67
# 2015-03-03    13.06
# 2015-03-04    12.92
# 2015-03-05    13.45
# 2015-03-06    14.48
# Name: high, dtype: float64

# %% [markdown]
# ## 替换 a.replace 默认不修改原值
#
# a.replace(to_replace=, value=, inplace=)
#
# - to_replace:替换前的值
# - value:替换后的值
# - inplace=True 修改原值

# %%
a = pd.Series([1, 2, 3, 3, 5])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# dtype: int64

# %%
a.replace(to_replace=3, value=4)
# Out:
# 0    1
# 1    2
# 2    4
# 3    4
# 4    5
# dtype: int64

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# dtype: int64

# %% [markdown]
# # df.to_func

# %%
data = pd.read_csv("../data/stock_day.csv")
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875   53782.64   46738.65   55576.11      2.39
# 2018-02-26  22.406  21.955  22.942   40827.52   42736.34   56007.50      1.53
# 2018-02-23  21.938  21.929  23.022   35119.58   41871.97   56372.85      1.32
# 2018-02-22  21.446  21.909  23.137   35397.58   39904.78   60149.60      0.90
# 2018-02-14  21.366  21.923  23.253   33590.21   42935.74   61716.11      0.58
# ...            ...     ...     ...        ...        ...        ...       ...
# 2015-03-06  13.112  13.112  13.112  115090.18  115090.18  115090.18      6.16
# 2015-03-05  12.820  12.820  12.820   98904.79   98904.79   98904.79      3.19
# 2015-03-04  12.707  12.707  12.707  100812.93  100812.93  100812.93      2.30
# 2015-03-03  12.610  12.610  12.610  117681.67  117681.67  117681.67      4.76
# 2015-03-02  12.520  12.520  12.520   96291.73   96291.73   96291.73      3.30
#
# [643 rows x 14 columns]

# %%
data.dtypes
# Out:
# open            float64
# high            float64
# close           float64
# low             float64
# volume          float64
# price_change    float64
# p_change        float64
# ma5             float64
# ma10            float64
# ma20            float64
# v_ma5           float64
# v_ma10          float64
# v_ma20          float64
# turnover        float64
# dtype: object

# %% [markdown]
# ## to_numpy()

# %%
data["open"].to_numpy()
# Out:
# array([23.53, 22.8 , 22.88, 22.25, 21.49, 21.4 , 20.7 , 21.2 , 21.79,
#        22.69, 22.8 , 22.45, 22.4 , 23.71, 23.85, 23.71, 24.4 , 24.27,
#        24.99, 25.49, 25.15, 25.14, 24.6 , 24.4 , 24.42, 23.4 , 24.01,
#        23.7 , 23.67, 24.1 , 24.6 , 24.12, 24.  , 22.79, 22.42, 22.3 ,
#        22.34, 22.23, 22.25, 21.73, 22.81, 23.21, 23.39, 23.61, 23.23,
#        23.  , 23.4 , 23.65, 23.99, 22.61, 22.61, 22.4 , 21.98, 21.66,
#        22.91, 23.91, 24.04, 24.37, 24.66, 24.01, 24.4 , 24.1 , 25.3 ,
#        25.21, 24.6 , 25.55, 28.  , 28.1 , 29.3 , 28.  , 28.61, 28.78,
#        28.88, 28.8 , 28.6 , 28.67, 28.86, 31.8 , 33.85, 32.62, 32.56,
#        31.45, 29.3 , 27.86, 28.2 , 29.  , 29.2 , 25.61, 25.63, 25.3 ,
#        26.4 , 26.26, 26.28, 27.26, 27.12, 27.8 , 27.49, 27.58, 26.52,
#        24.87, 25.78, 27.  , 26.03, 25.66, 25.95, 26.66, 26.58, 26.7 ,
#        27.2 , 27.18, 26.9 , 25.5 , 24.41, 23.51, 23.76, 24.45, 25.33,
#        24.16, 23.25, 23.45, 23.45, 22.5 , 22.87, 23.9 , 22.55, 22.6 ,
#        21.75, 21.8 , 21.37, 21.52, 21.1 , 21.85, 21.45, 21.62, 21.62,
#        21.6 , 22.1 , 22.18, 22.13, 22.65, 22.78, 22.6 , 23.39, 23.53,
#        23.07, 22.8 , 22.75, 22.52, 21.14, 20.63, 22.64, 23.28, 23.6 ,
#        22.26, 22.99, 21.11, 20.8 , 20.86, 20.59, 21.97, 21.59, 21.6 ,
#        21.78, 22.2 , 23.1 , 23.3 , 24.  , 23.32, 23.  , 23.75, 21.  ,
#        20.41, 19.33, 19.31, 18.25, 18.8 , 19.2 , 19.35, 18.59, 18.74,
#        18.16, 18.15, 17.9 , 17.85, 17.1 , 16.95, 17.2 , 17.75, 17.85,
#        17.81, 17.8 , 17.87, 17.5 , 17.3 , 17.85, 18.35, 18.63, 18.53,
#        18.58, 19.1 , 19.31, 19.28, 19.2 , 18.87, 18.9 , 18.85, 18.88,
#        19.58, 19.49, 20.07, 21.3 , 20.61, 20.67, 21.21, 21.3 , 20.26,
#        20.36, 21.3 , 20.81, 21.  , 19.73, 19.9 , 19.68, 19.8 , 19.78,
#        19.91, 19.5 , 19.88, 20.19, 20.47, 20.4 , 20.6 , 20.6 , 20.8 ,
#        20.52, 20.92, 20.96, 21.17, 21.3 , 21.88, 22.13, 21.79, 22.  ,
#        21.61, 21.52, 21.82, 22.08, 20.99, 21.35, 21.7 , 21.46, 22.17,
#        21.57, 21.5 , 20.75, 20.38, 20.72, 20.52, 20.55, 19.97, 19.35,
#        19.13, 19.3 , 19.15, 19.29, 19.11, 18.63, 18.67, 18.65, 18.51,
#        19.95, 20.26, 20.05, 20.31, 20.22, 20.38, 20.  , 19.78, 19.44,
#        19.4 , 19.6 , 19.38, 19.59, 19.68, 19.81, 20.46, 18.5 , 18.49,
#        18.45, 18.5 , 18.53, 17.98, 18.11, 19.04, 19.48, 20.91, 21.3 ,
#        21.14, 21.18, 20.85, 21.58, 21.5 , 22.21, 25.  , 24.5 , 24.36,
#        25.22, 24.9 , 24.48, 24.4 , 23.17, 23.11, 23.17, 23.16, 23.8 ,
#        24.1 , 23.78, 24.1 , 23.89, 23.25, 21.61, 21.15, 21.15, 21.25,
#        21.35, 21.14, 21.99, 22.2 , 22.43, 22.3 , 21.59, 21.9 , 21.19,
#        20.85, 19.88, 19.3 , 21.03, 21.06, 20.95, 20.78, 21.16, 21.95,
#        21.8 , 22.1 , 22.5 , 23.92, 24.8 , 23.2 , 22.74, 22.57, 22.33,
#        20.85, 20.92, 21.12, 21.87, 21.79, 21.8 , 21.88, 22.41, 22.08,
#        22.6 , 22.41, 22.51, 21.81, 21.6 , 20.77, 21.09, 21.44, 21.14,
#        21.41, 22.15, 21.79, 21.  , 20.55, 20.37, 20.92, 21.98, 21.82,
#        22.15, 20.17, 19.41, 18.31, 18.17, 18.3 , 18.  , 17.69, 17.6 ,
#        17.88, 17.82, 18.  , 19.5 , 18.66, 16.96, 15.24, 15.02, 14.97,
#        15.25, 15.48, 15.5 , 15.17, 15.84, 15.1 , 14.4 , 14.02, 14.82,
#        15.15, 16.5 , 15.98, 16.56, 16.35, 15.92, 16.12, 15.6 , 15.11,
#        14.68, 15.02, 14.52, 14.5 , 14.15, 13.99, 13.59, 13.96, 14.64,
#        15.76, 15.78, 15.5 , 15.7 , 16.05, 15.55, 14.97, 15.71, 14.86,
#        15.45, 15.9 , 16.59, 18.5 , 19.7 , 19.9 , 19.  , 22.8 , 21.9 ,
#        21.88, 21.86, 23.2 , 23.18, 24.05, 23.97, 23.8 , 24.2 , 23.53,
#        22.5 , 22.59, 22.24, 21.61, 21.81, 21.85, 21.06, 21.93, 21.45,
#        21.1 , 20.66, 21.3 , 20.38, 21.18, 23.35, 23.85, 23.4 , 23.26,
#        24.55, 23.93, 23.72, 26.17, 27.62, 24.51, 24.1 , 24.62, 24.2 ,
#        23.5 , 22.04, 22.18, 22.3 , 20.95, 20.89, 20.35, 20.85, 21.02,
#        21.9 , 21.49, 23.32, 21.21, 18.65, 19.96, 19.86, 20.55, 20.32,
#        18.61, 18.15, 16.61, 16.2 , 16.11, 16.03, 15.3 , 14.96, 14.95,
#        15.5 , 15.22, 14.94, 14.53, 13.9 , 14.1 , 14.58, 13.43, 13.74,
#        16.62, 15.  , 14.  , 13.95, 12.89, 12.92, 12.3 , 14.78, 16.13,
#        15.4 , 15.5 , 17.  , 17.29, 20.  , 20.62, 20.98, 19.  , 22.4 ,
#        21.67, 21.61, 20.23, 19.35, 19.6 , 18.22, 17.47, 16.94, 17.4 ,
#        16.2 , 17.39, 17.71, 19.44, 19.12, 18.76, 22.3 , 24.  , 23.2 ,
#        21.24, 20.85, 21.1 , 20.5 , 19.98, 22.78, 26.4 , 25.63, 22.2 ,
#        25.  , 23.82, 26.5 , 27.  , 28.  , 27.6 , 26.8 , 30.98, 30.94,
#        31.45, 30.48, 34.99, 34.69, 33.17, 34.1 , 30.46, 28.4 , 27.37,
#        27.42, 28.25, 27.5 , 25.86, 25.5 , 27.95, 29.66, 29.92, 29.3 ,
#        29.87, 27.5 , 24.1 , 23.68, 22.28, 22.35, 20.84, 21.21, 20.78,
#        20.31, 19.1 , 19.56, 20.85, 22.41, 22.2 , 22.2 , 21.73, 22.93,
#        22.56, 21.82, 22.  , 21.9 , 21.  , 21.7 , 22.6 , 24.63, 23.45,
#        21.45, 19.6 , 19.55, 18.28, 17.6 , 16.54, 16.44, 16.21, 16.18,
#        16.78, 15.99, 14.9 , 15.14, 15.97, 15.38, 15.34, 15.38, 15.2 ,
#        15.18, 14.9 , 14.52, 14.13, 14.11, 14.8 , 14.2 , 14.14, 13.17,
#        12.88, 12.8 , 12.52, 12.25])

# %% [markdown]
# ## to_dict(orient="records")

# %%
data.to_dict(orient="records")
# Out:
# [{'open': 23.53,
#   'high': 25.88,
#   'close': 24.16,
#   'low': 23.53,
#   'volume': 95578.03,
#   'price_change': 0.63,
#   'p_change': 2.68,
#   'ma5': 22.942,
#   'ma10': 22.142,
#   'ma20': 22.875,
#   'v_ma5': 53782.64,
#   'v_ma10': 46738.65,
#   'v_ma20': 55576.11,
#   'turnover': 2.39},
#  {'open': 22.8,
#   'high': 23.78,
#   'close': 23.53,
#   'low': 22.8,
#   'volume': 60985.11,
#   'price_change': 0.69,
#   'p_change': 3.02,
#   'ma5': 22.406,
#   'ma10': 21.955,
#   'ma20': 22.942,
#   'v_ma5': 40827.52,
#   'v_ma10': 42736.34,
#   'v_ma20': 56007.5,
#   'turnover': 1.53},
#  {'open': 22.88,
#   'high': 23.37,
#   'close': 22.82,
#   'low': 22.71,
#   'volume': 52914.01,
#   'price_change': 0.54,
#   'p_change': 2.42,
#   'ma5': 21.938,
#   'ma10': 21.929,
#   'ma20': 23.022,
#   'v_ma5': 35119.58,
#   'v_ma10': 41871.97,
#   'v_ma20': 56372.85,
#   'turnover': 1.32},
#  {'open': 22.25,
#   'high': 22.76,
#   'close': 22.28,
#   'low': 22.02,
#   'volume': 36105.01,
#   'price_change': 0.36,
#   'p_change': 1.64,
#   'ma5': 21.446,
#   'ma10': 21.909,
#   'ma20': 23.137,
#   'v_ma5': 35397.58,
#   'v_ma10': 39904.78,
#   'v_ma20': 60149.6,
#   'turnover': 0.9},
#  {'open': 21.49,
#   'high': 21.99,
#   'close': 21.92,
#   'low': 21.48,
#   'volume': 23331.04,
#   'price_change': 0.44,
#   'p_change': 2.05,
#   'ma5': 21.366,
#   'ma10': 21.923,
#   'ma20': 23.253,
#   'v_ma5': 33590.21,
#   'v_ma10': 42935.74,
#   'v_ma20': 61716.11,
#   'turnover': 0.58},
#  {'open': 21.4,
#   'high': 21.9,
#   'close': 21.48,
#   'low': 21.31,
#   'volume': 30802.45,
#   'price_change': 0.28,
#   'p_change': 1.32,
#   'ma5': 21.342,
#   'ma10': 22.103,
#   'ma20': 23.387,
#   'v_ma5': 39694.65,
#   'v_ma10': 45518.14,
#   'v_ma20': 65161.68,
#   'turnover': 0.77},
#  {'open': 20.7,
#   'high': 21.4,
#   'close': 21.19,
#   'low': 20.63,
#   'volume': 32445.39,
#   'price_change': 0.82,
#   'p_change': 4.03,
#   'ma5': 21.504,
#   'ma10': 22.338,
#   'ma20': 23.533,
#   'v_ma5': 44645.16,
#   'v_ma10': 45679.94,
#   'v_ma20': 68686.33,
#   'turnover': 0.81},
#  {'open': 21.2,
#   'high': 21.46,
#   'close': 20.36,
#   'low': 20.19,
#   'volume': 54304.01,
#   'price_change': -1.5,
#   'p_change': -6.86,
#   'ma5': 21.92,
#   'ma10': 22.596,
#   'ma20': 23.645,
#   'v_ma5': 48624.36,
#   'v_ma10': 48982.38,
#   'v_ma20': 70552.47,
#   'turnover': 1.36},
#  {'open': 21.79,
#   'high': 22.09,
#   'close': 21.88,
#   'low': 21.75,
#   'volume': 27068.16,
#   'price_change': 0.09,
#   'p_change': 0.41,
#   'ma5': 22.372,
#   'ma10': 23.009,
#   'ma20': 23.839,
#   'v_ma5': 44411.98,
#   'v_ma10': 48612.16,
#   'v_ma20': 73852.45,
#   'turnover': 0.68},
#  {'open': 22.69,
#   'high': 23.11,
#   'close': 21.8,
#   'low': 21.29,
#   'volume': 53853.25,
#   'price_change': -0.5,
#   'p_change': -2.24,
#   'ma5': 22.48,
#   'ma10': 23.258,
#   'ma20': 23.929,
#   'v_ma5': 52281.28,
#   'v_ma10': 56315.11,
#   'v_ma20': 74925.33,
#   'turnover': 1.35},
#  {'open': 22.8,
#   'high': 23.55,
#   'close': 22.29,
#   'low': 22.2,
#   'volume': 55555.0,
#   'price_change': -0.97,
#   'p_change': -4.17,
#   'ma5': 22.864,
#   'ma10': 23.607,
#   'ma20': 24.029,
#   'v_ma5': 51341.63,
#   'v_ma10': 64413.58,
#   'v_ma20': 75738.95,
#   'turnover': 1.39},
#  {'open': 22.45,
#   'high': 23.39,
#   'close': 23.27,
#   'low': 22.25,
#   'volume': 52341.39,
#   'price_change': 0.65,
#   'p_change': 2.87,
#   'ma5': 23.172,
#   'ma10': 23.928,
#   'ma20': 24.112,
#   'v_ma5': 46714.72,
#   'v_ma10': 69278.66,
#   'v_ma20': 77070.0,
#   'turnover': 1.31},
#  {'open': 22.4,
#   'high': 22.7,
#   'close': 22.62,
#   'low': 21.53,
#   'volume': 33242.11,
#   'price_change': 0.2,
#   'p_change': 0.89,
#   'ma5': 23.272,
#   'ma10': 24.114,
#   'ma20': 24.184,
#   'v_ma5': 49340.4,
#   'v_ma10': 70873.73,
#   'v_ma20': 79929.71,
#   'turnover': 0.83},
#  {'open': 23.71,
#   'high': 23.86,
#   'close': 22.42,
#   'low': 22.22,
#   'volume': 66414.64,
#   'price_change': -1.3,
#   'p_change': -5.48,
#   'ma5': 23.646,
#   'ma10': 24.365,
#   'ma20': 24.279,
#   'v_ma5': 52812.35,
#   'v_ma10': 80394.43,
#   'v_ma20': 88480.92,
#   'turnover': 1.66},
#  {'open': 23.85,
#   'high': 23.98,
#   'close': 23.72,
#   'low': 23.31,
#   'volume': 49155.02,
#   'price_change': -0.11,
#   'p_change': -0.46,
#   'ma5': 24.036,
#   'ma10': 24.583,
#   'ma20': 24.411,
#   'v_ma5': 60348.94,
#   'v_ma10': 80496.48,
#   'v_ma20': 91666.75,
#   'turnover': 1.23},
#  {'open': 23.71,
#   'high': 24.08,
#   'close': 23.83,
#   'low': 23.7,
#   'volume': 32420.43,
#   'price_change': 0.05,
#   'p_change': 0.21,
#   'ma5': 24.35,
#   'ma10': 24.671,
#   'ma20': 24.365,
#   'v_ma5': 77485.53,
#   'v_ma10': 84805.23,
#   'v_ma20': 92943.35,
#   'turnover': 0.81},
#  {'open': 24.4,
#   'high': 24.63,
#   'close': 23.77,
#   'low': 23.72,
#   'volume': 65469.81,
#   'price_change': -0.73,
#   'p_change': -2.98,
#   'ma5': 24.684,
#   'ma10': 24.728,
#   'ma20': 24.294,
#   'v_ma5': 91842.6,
#   'v_ma10': 91692.73,
#   'v_ma20': 93456.22,
#   'turnover': 1.64},
#  {'open': 24.27,
#   'high': 24.74,
#   'close': 24.49,
#   'low': 24.22,
#   'volume': 50601.83,
#   'price_change': 0.11,
#   'p_change': 0.45,
#   'ma5': 24.956,
#   'ma10': 24.694,
#   'ma20': 24.221,
#   'v_ma5': 92407.05,
#   'v_ma10': 92122.56,
#   'v_ma20': 91980.51,
#   'turnover': 1.27},
#  {'open': 24.99,
#   'high': 24.99,
#   'close': 24.37,
#   'low': 24.23,
#   'volume': 104097.59,
#   'price_change': -0.93,
#   'p_change': -3.68,
#   'ma5': 25.084,
#   'ma10': 24.669,
#   'ma20': 24.109,
#   'v_ma5': 107976.51,
#   'v_ma10': 99092.73,
#   'v_ma20': 92262.67,
#   'turnover': 2.61},
#  {'open': 25.49,
#   'high': 26.28,
#   'close': 25.29,
#   'low': 25.2,
#   'volume': 134838.0,
#   'price_change': -0.2,
#   'p_change': -0.79,
#   'ma5': 25.13,
#   'ma10': 24.599,
#   'ma20': 23.997,
#   'v_ma5': 100644.02,
#   'v_ma10': 93535.55,
#   'v_ma20': 89522.22,
#   'turnover': 3.37},
#  {'open': 25.15,
#   'high': 25.53,
#   'close': 25.5,
#   'low': 24.93,
#   'volume': 104205.76,
#   'price_change': 0.39,
#   'p_change': 1.55,
#   'ma5': 24.992,
#   'ma10': 24.45,
#   'ma20': 23.844,
#   'v_ma5': 92124.92,
#   'v_ma10': 87064.33,
#   'v_ma20': 85876.8,
#   'turnover': 2.61},
#  {'open': 25.14,
#   'high': 25.4,
#   'close': 25.13,
#   'low': 24.75,
#   'volume': 68292.08,
#   'price_change': -0.01,
#   'p_change': -0.04,
#   'ma5': 24.772,
#   'ma10': 24.296,
#   'ma20': 23.644,
#   'v_ma5': 91542.85,
#   'v_ma10': 84861.33,
#   'v_ma20': 84970.0,
#   'turnover': 1.71},
#  {'open': 24.6,
#   'high': 25.34,
#   'close': 25.13,
#   'low': 24.42,
#   'volume': 128449.11,
#   'price_change': 0.53,
#   'p_change': 2.15,
#   'ma5': 24.432,
#   'ma10': 24.254,
#   'ma20': 23.537,
#   'v_ma5': 91838.07,
#   'v_ma10': 88985.7,
#   'v_ma20': 82975.1,
#   'turnover': 3.21},
#  {'open': 24.4,
#   'high': 24.88,
#   'close': 24.6,
#   'low': 24.3,
#   'volume': 67435.14,
#   'price_change': 0.01,
#   'p_change': 0.04,
#   'ma5': 24.254,
#   'ma10': 24.192,
#   'ma20': 23.441,
#   'v_ma5': 90208.95,
#   'v_ma10': 96567.41,
#   'v_ma20': 78252.92,
#   'turnover': 1.69},
#  {'open': 24.42,
#   'high': 24.92,
#   'close': 24.6,
#   'low': 23.8,
#   'volume': 92242.51,
#   'price_change': 0.2,
#   'p_change': 0.82,
#   'ma5': 24.068,
#   'ma10': 24.239,
#   'ma20': 23.378,
#   'v_ma5': 86427.08,
#   'v_ma10': 102837.01,
#   'v_ma20': 77049.61,
#   'turnover': 2.31},
#  {'open': 23.4,
#   'high': 24.6,
#   'close': 24.4,
#   'low': 23.3,
#   'volume': 101295.42,
#   'price_change': 0.96,
#   'p_change': 4.1,
#   'ma5': 23.908,
#   'ma10': 24.058,
#   'ma20': 23.321,
#   'v_ma5': 82003.73,
#   'v_ma10': 101081.47,
#   'v_ma20': 74590.92,
#   'turnover': 2.54},
#  {'open': 24.01,
#   'high': 24.23,
#   'close': 23.43,
#   'low': 23.3,
#   'volume': 69768.17,
#   'price_change': -0.8,
#   'p_change': -3.3,
#   'ma5': 23.82,
#   'ma10': 23.86,
#   'ma20': 23.257,
#   'v_ma5': 78179.81,
#   'v_ma10': 95219.71,
#   'v_ma20': 71006.65,
#   'turnover': 1.75},
#  {'open': 23.7,
#   'high': 25.15,
#   'close': 24.24,
#   'low': 23.42,
#   'volume': 120303.53,
#   'price_change': 0.56,
#   'p_change': 2.37,
#   'ma5': 24.076,
#   'ma10': 23.748,
#   'ma20': 23.236,
#   'v_ma5': 86133.33,
#   'v_ma10': 91838.46,
#   'v_ma20': 69690.35,
#   'turnover': 3.01},
#  {'open': 23.67,
#   'high': 23.85,
#   'close': 23.67,
#   'low': 23.21,
#   'volume': 48525.75,
#   'price_change': -0.12,
#   'p_change': -0.5,
#   'ma5': 24.13,
#   'ma10': 23.548,
#   'ma20': 23.197,
#   'v_ma5': 102925.87,
#   'v_ma10': 85432.61,
#   'v_ma20': 65928.23,
#   'turnover': 1.21},
#  {'open': 24.1,
#   'high': 24.6,
#   'close': 23.8,
#   'low': 23.4,
#   'volume': 70125.79,
#   'price_change': -0.14,
#   'p_change': -0.58,
#   'ma5': 24.41,
#   'ma10': 23.394,
#   'ma20': 23.204,
#   'v_ma5': 119246.95,
#   'v_ma10': 85508.89,
#   'v_ma20': 66934.89,
#   'turnover': 1.76},
#  {'open': 24.6,
#   'high': 24.78,
#   'close': 23.96,
#   'low': 23.82,
#   'volume': 82175.82,
#   'price_change': -0.76,
#   'p_change': -3.07,
#   'ma5': 24.208,
#   'ma10': 23.237,
#   'ma20': 23.213,
#   'v_ma5': 120159.21,
#   'v_ma10': 84689.28,
#   'v_ma20': 69688.92,
#   'turnover': 2.06},
#  {'open': 24.12,
#   'high': 24.95,
#   'close': 24.71,
#   'low': 24.01,
#   'volume': 109535.76,
#   'price_change': 0.2,
#   'p_change': 0.82,
#   'ma5': 23.9,
#   'ma10': 22.992,
#   'ma20': 23.153,
#   'v_ma5': 112259.6,
#   'v_ma10': 85078.67,
#   'v_ma20': 67644.48,
#   'turnover': 2.74},
#  {'open': 24.0,
#   'high': 25.4,
#   'close': 24.51,
#   'low': 23.7,
#   'volume': 204266.23,
#   'price_change': -0.56,
#   'p_change': -2.23,
#   'ma5': 23.42,
#   'ma10': 22.82,
#   'ma20': 23.048,
#   'v_ma5': 97543.6,
#   'v_ma10': 76964.5,
#   'v_ma20': 64853.8,
#   'turnover': 5.11},
#  {'open': 22.79,
#   'high': 25.07,
#   'close': 25.07,
#   'low': 22.51,
#   'volume': 130131.15,
#   'price_change': 2.28,
#   'p_change': 10.0,
#   'ma5': 22.966,
#   'ma10': 22.69,
#   'ma20': 22.935,
#   'v_ma5': 67939.35,
#   'v_ma10': 59938.43,
#   'v_ma20': 57071.47,
#   'turnover': 3.26},
#  {'open': 22.42,
#   'high': 22.83,
#   'close': 22.79,
#   'low': 22.18,
#   'volume': 74687.1,
#   'price_change': 0.38,
#   'p_change': 1.7,
#   'ma5': 22.378,
#   'ma10': 22.516,
#   'ma20': 22.785,
#   'v_ma5': 51770.82,
#   'v_ma10': 51262.21,
#   'v_ma20': 53198.15,
#   'turnover': 1.87},
#  {'open': 22.3,
#   'high': 22.54,
#   'close': 22.42,
#   'low': 22.05,
#   'volume': 42677.76,
#   'price_change': 0.12,
#   'p_change': 0.54,
#   'ma5': 22.266,
#   'ma10': 22.583,
#   'ma20': 22.73,
#   'v_ma5': 49219.34,
#   'v_ma10': 48100.37,
#   'v_ma20': 53397.23,
#   'turnover': 1.07},
#  {'open': 22.34,
#   'high': 22.46,
#   'close': 22.31,
#   'low': 22.02,
#   'volume': 35955.75,
#   'price_change': 0.08,
#   'p_change': 0.36,
#   'ma5': 22.084,
#   'ma10': 22.654,
#   'ma20': 22.755,
#   'v_ma5': 57897.75,
#   'v_ma10': 46793.59,
#   'v_ma20': 55537.48,
#   'turnover': 0.9},
#  {'open': 22.23,
#   'high': 22.84,
#   'close': 22.24,
#   'low': 22.12,
#   'volume': 56245.01,
#   'price_change': 0.11,
#   'p_change': 0.5,
#   'ma5': 22.22,
#   'ma10': 22.723,
#   'ma20': 22.849,
#   'v_ma5': 56385.4,
#   'v_ma10': 47542.23,
#   'v_ma20': 55915.74,
#   'turnover': 1.41},
#  {'open': 22.25,
#   'high': 22.57,
#   'close': 22.13,
#   'low': 21.8,
#   'volume': 49288.5,
#   'price_change': -0.11,
#   'p_change': -0.49,
#   'ma5': 22.414,
#   'ma10': 22.846,
#   'ma20': 22.949,
#   'v_ma5': 51937.5,
#   'v_ma10': 46423.84,
#   'v_ma20': 55602.16,
#   'turnover': 1.23},
#  {'open': 21.73,
#   'high': 22.66,
#   'close': 22.23,
#   'low': 21.73,
#   'volume': 61929.7,
#   'price_change': 0.72,
#   'p_change': 3.35,
#   'ma5': 22.654,
#   'ma10': 23.014,
#   'ma20': 23.057,
#   'v_ma5': 50753.59,
#   'v_ma10': 48360.9,
#   'v_ma20': 55920.67,
#   'turnover': 1.55},
#  {'open': 22.81,
#   'high': 22.93,
#   'close': 21.51,
#   'low': 21.11,
#   'volume': 86069.77,
#   'price_change': -1.47,
#   'p_change': -6.4,
#   'ma5': 22.9,
#   'ma10': 23.189,
#   'ma20': 23.181,
#   'v_ma5': 46981.39,
#   'v_ma10': 54688.57,
#   'v_ma20': 55274.61,
#   'turnover': 2.15},
#  {'open': 23.21,
#   'high': 23.39,
#   'close': 22.99,
#   'low': 22.9,
#   'volume': 28394.0,
#   'price_change': -0.21,
#   'p_change': -0.91,
#   'ma5': 23.224,
#   'ma10': 23.313,
#   'ma20': 23.316,
#   'v_ma5': 35689.43,
#   'v_ma10': 50210.29,
#   'v_ma20': 53887.77,
#   'turnover': 0.71},
#  {'open': 23.39,
#   'high': 23.5,
#   'close': 23.21,
#   'low': 22.86,
#   'volume': 34005.55,
#   'price_change': -0.11,
#   'p_change': -0.47,
#   'ma5': 23.226,
#   'ma10': 23.275,
#   'ma20': 23.389,
#   'v_ma5': 38699.06,
#   'v_ma10': 52743.1,
#   'v_ma20': 55126.09,
#   'turnover': 0.85},
#  {'open': 23.61,
#   'high': 23.96,
#   'close': 23.33,
#   'low': 23.2,
#   'volume': 43368.92,
#   'price_change': -0.14,
#   'p_change': -0.6,
#   'ma5': 23.278,
#   'ma10': 23.18,
#   'ma20': 23.43,
#   'v_ma5': 40910.18,
#   'v_ma10': 54204.51,
#   'v_ma20': 57245.14,
#   'turnover': 1.09},
#  {'open': 23.23,
#   'high': 23.66,
#   'close': 23.46,
#   'low': 23.23,
#   'volume': 43068.7,
#   'price_change': 0.31,
#   'p_change': 1.34,
#   'ma5': 23.374,
#   'ma10': 23.053,
#   'ma20': 23.526,
#   'v_ma5': 45968.22,
#   'v_ma10': 55134.09,
#   'v_ma20': 58490.17,
#   'turnover': 1.08},
#  {'open': 23.0,
#   'high': 23.49,
#   'close': 23.13,
#   'low': 22.83,
#   'volume': 29610.0,
#   'price_change': 0.12,
#   'p_change': 0.52,
#   'ma5': 23.478,
#   'ma10': 22.877,
#   'ma20': 23.617,
#   'v_ma5': 62395.75,
#   'v_ma10': 58694.09,
#   'v_ma20': 60331.46,
#   'turnover': 0.74},
#  {'open': 23.4,
#   'high': 23.4,
#   'close': 23.0,
#   'low': 22.85,
#   'volume': 43442.15,
#   'price_change': -0.46,
#   'p_change': -1.96,
#   'ma5': 23.402,
#   'ma10': 22.856,
#   'ma20': 23.715,
#   'v_ma5': 64731.15,
#   'v_ma10': 64281.37,
#   'v_ma20': 65134.62,
#   'turnover': 1.09},
#  {'open': 23.65,
#   'high': 23.77,
#   'close': 23.47,
#   'low': 23.22,
#   'volume': 45061.12,
#   'price_change': -0.33,
#   'p_change': -1.39,
#   'ma5': 23.324,
#   'ma10': 22.974,
#   'ma20': 23.869,
#   'v_ma5': 66787.14,
#   'v_ma10': 64289.26,
#   'v_ma20': 71322.17,
#   'turnover': 1.13},
#  {'open': 23.99,
#   'high': 24.38,
#   'close': 23.81,
#   'low': 23.6,
#   'volume': 68659.12,
#   'price_change': -0.15,
#   'p_change': -0.63,
#   'ma5': 23.082,
#   'ma10': 23.052,
#   'ma20': 24.104,
#   'v_ma5': 67498.84,
#   'v_ma10': 64780.47,
#   'v_ma20': 73475.4,
#   'turnover': 1.72},
#  {'open': 22.61,
#   'high': 24.14,
#   'close': 23.98,
#   'low': 22.61,
#   'volume': 125206.36,
#   'price_change': 1.21,
#   'p_change': 5.31,
#   'ma5': 22.732,
#   'ma10': 23.1,
#   'ma20': 24.337,
#   'v_ma5': 64299.97,
#   'v_ma10': 63480.44,
#   'v_ma20': 76113.42,
#   'turnover': 3.13},
#  {'open': 22.61,
#   'high': 22.94,
#   'close': 22.75,
#   'low': 22.5,
#   'volume': 41287.0,
#   'price_change': 0.14,
#   'p_change': 0.62,
#   'ma5': 22.276,
#   'ma10': 23.172,
#   'ma20': 24.605,
#   'v_ma5': 54992.43,
#   'v_ma10': 55860.66,
#   'v_ma20': 82041.76,
#   'turnover': 1.03},
#  {'open': 22.4,
#   'high': 22.9,
#   'close': 22.61,
#   'low': 22.04,
#   'volume': 53722.08,
#   'price_change': 0.35,
#   'p_change': 1.57,
#   'ma5': 22.31,
#   'ma10': 23.318,
#   'ma20': 24.88,
#   'v_ma5': 63831.59,
#   'v_ma10': 57565.25,
#   'v_ma20': 87775.07,
#   'turnover': 1.34},
#  {'open': 21.98,
#   'high': 22.48,
#   'close': 22.26,
#   'low': 21.92,
#   'volume': 48619.64,
#   'price_change': 0.22,
#   'p_change': 1.0,
#   'ma5': 22.624,
#   'ma10': 23.502,
#   'ma20': 25.153,
#   'v_ma5': 61791.38,
#   'v_ma10': 57509.09,
#   'v_ma20': 91369.88,
#   'turnover': 1.22},
#  {'open': 21.66,
#   'high': 22.1,
#   'close': 22.06,
#   'low': 21.51,
#   'volume': 52664.77,
#   'price_change': 0.36,
#   'p_change': 1.66,
#   'ma5': 23.022,
#   'ma10': 23.679,
#   'ma20': 25.459,
#   'v_ma5': 62062.1,
#   'v_ma10': 60285.78,
#   'v_ma20': 98491.69,
#   'turnover': 1.32},
#  {'open': 22.91,
#   'high': 23.26,
#   'close': 21.7,
#   'low': 21.65,
#   'volume': 78668.67,
#   'price_change': -1.22,
#   'p_change': -5.32,
#   'ma5': 23.468,
#   'ma10': 23.999,
#   'ma20': 25.808,
#   'v_ma5': 62660.91,
#   'v_ma10': 61846.25,
#   'v_ma20': 104051.13,
#   'turnover': 1.97},
#  {'open': 23.91,
#   'high': 24.15,
#   'close': 22.92,
#   'low': 22.85,
#   'volume': 85482.8,
#   'price_change': -1.27,
#   'p_change': -5.25,
#   'ma5': 24.068,
#   'ma10': 24.357,
#   'ma20': 26.172,
#   'v_ma5': 56728.88,
#   'v_ma10': 61968.83,
#   'v_ma20': 108773.06,
#   'turnover': 2.14},
#  {'open': 24.04,
#   'high': 24.49,
#   'close': 24.18,
#   'low': 24.04,
#   'volume': 43521.0,
#   'price_change': -0.04,
#   'p_change': -0.17,
#   'ma5': 24.326,
#   'ma10': 24.574,
#   'ma20': 26.435,
#   'v_ma5': 51298.9,
#   'v_ma10': 65987.87,
#   'v_ma20': 112043.75,
#   'turnover': 1.09},
#  {'open': 24.37,
#   'high': 24.76,
#   'close': 24.25,
#   'low': 24.05,
#   'volume': 49973.27,
#   'price_change': -0.05,
#   'p_change': -0.21,
#   'ma5': 24.38,
#   'ma10': 24.764,
#   'ma20': 26.634,
#   'v_ma5': 53226.8,
#   'v_ma10': 78355.08,
#   'v_ma20': 123826.01,
#   'turnover': 1.25},
#  {'open': 24.66,
#   'high': 24.8,
#   'close': 24.29,
#   'low': 23.96,
#   'volume': 55658.83,
#   'price_change': -0.4,
#   'p_change': -1.62,
#   'ma5': 24.336,
#   'ma10': 25.156,
#   'ma20': 26.944,
#   'v_ma5': 58509.45,
#   'v_ma10': 82170.33,
#   'v_ma20': 136951.4,
#   'turnover': 1.39},
#  {'open': 24.01,
#   'high': 24.9,
#   'close': 24.7,
#   'low': 24.0,
#   'volume': 49008.5,
#   'price_change': 0.5,
#   'p_change': 2.07,
#   'ma5': 24.53,
#   'ma10': 25.573,
#   'ma20': 27.421,
#   'v_ma5': 61031.58,
#   'v_ma10': 88746.39,
#   'v_ma20': 145784.73,
#   'turnover': 1.23},
#  {'open': 24.4,
#   'high': 24.95,
#   'close': 24.21,
#   'low': 24.01,
#   'volume': 58332.89,
#   'price_change': -0.23,
#   'p_change': -0.94,
#   'ma5': 24.646,
#   'ma10': 26.037,
#   'ma20': 27.908,
#   'v_ma5': 67208.79,
#   'v_ma10': 108222.87,
#   'v_ma20': 161417.35,
#   'turnover': 1.46},
#  {'open': 24.1,
#   'high': 24.7,
#   'close': 24.45,
#   'low': 24.09,
#   'volume': 53160.52,
#   'price_change': 0.43,
#   'p_change': 1.79,
#   'ma5': 24.822,
#   'ma10': 26.441,
#   'ma20': 28.3,
#   'v_ma5': 80676.85,
#   'v_ma10': 117984.89,
#   'v_ma20': 175389.32,
#   'turnover': 1.33},
#  {'open': 25.3,
#   'high': 25.43,
#   'close': 24.03,
#   'low': 23.98,
#   'volume': 76386.5,
#   'price_change': -1.24,
#   'p_change': -4.91,
#   'ma5': 25.148,
#   'ma10': 26.805,
#   'ma20': 28.733,
#   'v_ma5': 103483.37,
#   'v_ma10': 125230.68,
#   'v_ma20': 189422.51,
#   'turnover': 1.91},
#  {'open': 25.21,
#   'high': 25.9,
#   'close': 25.26,
#   'low': 24.84,
#   'volume': 68269.5,
#   'price_change': -0.03,
#   'p_change': -0.12,
#   'ma5': 25.976,
#   'ma10': 27.239,
#   'ma20': 29.152,
#   'v_ma5': 105831.21,
#   'v_ma10': 136697.6,
#   'v_ma20': 210698.95,
#   'turnover': 1.71},
#  {'open': 24.6,
#   'high': 25.98,
#   'close': 25.28,
#   'low': 24.56,
#   'volume': 79894.52,
#   'price_change': 0.17,
#   'p_change': 0.68,
#   'ma5': 26.616,
#   'ma10': 27.617,
#   'ma20': 29.376,
#   'v_ma5': 116461.2,
#   'v_ma10': 146256.01,
#   'v_ma20': 223732.84,
#   'turnover': 2.0},
#  {'open': 25.55,
#   'high': 25.58,
#   'close': 25.09,
#   'low': 23.46,
#   'volume': 125673.2,
#   'price_change': -0.98,
#   'p_change': -3.76,
#   'ma5': 27.428,
#   'ma10': 27.987,
#   'ma20': 29.514,
#   'v_ma5': 149236.94,
#   'v_ma10': 155577.28,
#   'v_ma20': 235402.64,
#   'turnover': 3.15},
#  {'open': 28.0,
#   'high': 28.15,
#   'close': 26.08,
#   'low': 25.91,
#   'volume': 167193.12,
#   'price_change': -2.09,
#   'p_change': -7.42,
#   'ma5': 28.06,
#   'ma10': 28.296,
#   'ma20': 29.749,
#   'v_ma5': 155292.94,
#   'v_ma10': 158099.63,
#   'v_ma20': 252443.7,
#   'turnover': 4.18},
#  {'open': 28.1,
#   'high': 28.72,
#   'close': 28.17,
#   'low': 28.0,
#   'volume': 88125.71,
#   'price_change': -0.3,
#   'p_change': -1.05,
#   'ma5': 28.462,
#   'ma10': 28.503,
#   'ma20': 29.862,
#   'v_ma5': 146977.99,
#   'v_ma10': 169296.94,
#   'v_ma20': 264662.55,
#   'turnover': 2.21},
#  {'open': 29.3,
#   'high': 29.3,
#   'close': 28.46,
#   'low': 28.3,
#   'volume': 121419.46,
#   'price_change': -0.86,
#   'p_change': -2.93,
#   'ma5': 28.502,
#   'ma10': 28.731,
#   'ma20': 29.811,
#   'v_ma5': 167563.98,
#   'v_ma10': 191732.48,
#   'v_ma20': 269280.79,
#   'turnover': 3.04},
#  {'open': 28.0,
#   'high': 29.89,
#   'close': 29.34,
#   'low': 27.68,
#   'volume': 243773.23,
#   'price_change': 1.1,
#   'p_change': 3.9,
#   'ma5': 28.618,
#   'ma10': 29.268,
#   'ma20': 29.673,
#   'v_ma5': 176050.82,
#   'v_ma10': 202823.06,
#   'v_ma20': 268677.48,
#   'turnover': 6.1},
#  {'open': 28.61,
#   'high': 29.23,
#   'close': 28.25,
#   'low': 28.09,
#   'volume': 155953.17,
#   'price_change': 0.16,
#   'p_change': 0.57,
#   'ma5': 28.546,
#   'ma10': 29.778,
#   'ma20': 29.477,
#   'v_ma5': 161917.62,
#   'v_ma10': 214611.83,
#   'v_ma20': 259871.29,
#   'turnover': 3.9},
#  {'open': 28.78,
#   'high': 28.99,
#   'close': 28.09,
#   'low': 27.88,
#   'volume': 125618.36,
#   'price_change': -0.28,
#   'p_change': -0.99,
#   'ma5': 28.532,
#   'ma10': 30.159,
#   'ma20': 29.324,
#   'v_ma5': 160906.32,
#   'v_ma10': 232793.74,
#   'v_ma20': 257734.07,
#   'turnover': 3.14},
#  {'open': 28.88,
#   'high': 29.09,
#   'close': 28.37,
#   'low': 27.76,
#   'volume': 191055.7,
#   'price_change': -0.67,
#   'p_change': -2.31,
#   'ma5': 28.544,
#   'ma10': 30.661,
#   'ma20': 29.237,
#   'v_ma5': 191615.9,
#   'v_ma10': 253614.34,
#   'v_ma20': 254168.58,
#   'turnover': 4.78},
#  {'open': 28.8,
#   'high': 29.7,
#   'close': 29.04,
#   'low': 28.11,
#   'volume': 163853.66,
#   'price_change': 0.06,
#   'p_change': 0.21,
#   'ma5': 28.96,
#   'ma10': 31.065,
#   'ma20': 29.132,
#   'v_ma5': 215900.97,
#   'v_ma10': 284700.31,
#   'v_ma20': 248910.25,
#   'turnover': 4.1},
#  {'open': 28.6,
#   'high': 29.37,
#   'close': 28.98,
#   'low': 28.42,
#   'volume': 173107.2,
#   'price_change': 0.8,
#   'p_change': 2.84,
#   'ma5': 29.918,
#   'ma10': 31.134,
#   'ma20': 28.995,
#   'v_ma5': 229595.3,
#   'v_ma10': 301209.67,
#   'v_ma20': 247155.94,
#   'turnover': 4.33},
#  {'open': 28.67,
#   'high': 28.74,
#   'close': 28.18,
#   'low': 27.76,
#   'volume': 150896.66,
#   'price_change': 0.03,
#   'p_change': 0.11,
#   'ma5': 31.01,
#   'ma10': 31.041,
#   'ma20': 28.902,
#   'v_ma5': 267306.04,
#   'v_ma10': 315227.99,
#   'v_ma20': 242961.71,
#   'turnover': 3.78},
#  {'open': 28.86,
#   'high': 29.62,
#   'close': 28.15,
#   'low': 28.03,
#   'volume': 279166.28,
#   'price_change': -2.3,
#   'p_change': -7.55,
#   'ma5': 31.786,
#   'ma10': 31.202,
#   'ma20': 28.861,
#   'v_ma5': 304681.17,
#   'v_ma10': 346787.77,
#   'v_ma20': 243949.88,
#   'turnover': 6.99},
#  {'open': 31.8,
#   'high': 31.8,
#   'close': 30.45,
#   'low': 30.45,
#   'volume': 312481.06,
#   'price_change': -3.38,
#   'p_change': -9.99,
#   'ma5': 32.778,
#   'ma10': 31.22,
#   'ma20': 28.843,
#   'v_ma5': 315612.77,
#   'v_ma10': 360028.16,
#   'v_ma20': 237874.8,
#   'turnover': 7.82},
#  {'open': 33.85,
#   'high': 34.34,
#   'close': 33.83,
#   'low': 33.1,
#   'volume': 232325.3,
#   'price_change': -0.61,
#   'p_change': -1.77,
#   'ma5': 33.17,
#   'ma10': 30.891,
#   'ma20': 28.684,
#   'v_ma5': 353499.64,
#   'v_ma10': 346829.1,
#   'v_ma20': 233701.92,
#   'turnover': 5.81},
#  {'open': 32.62,
#   'high': 35.22,
#   'close': 34.44,
#   'low': 32.2,
#   'volume': 361660.88,
#   'price_change': 2.38,
#   'p_change': 7.42,
#   'ma5': 32.35,
#   'ma10': 30.077,
#   'ma20': 28.406,
#   'v_ma5': 372824.04,
#   'v_ma10': 334531.9,
#   'v_ma20': 241075.48,
#   'turnover': 9.05},
#  {'open': 32.56,
#   'high': 34.4,
#   'close': 32.06,
#   'low': 31.85,
#   'volume': 337772.31,
#   'price_change': -1.05,
#   'p_change': -3.17,
#   'ma5': 31.072,
#   'ma10': 29.176,
#   'ma20': 28.01,
#   'v_ma5': 363149.95,
#   'v_ma10': 305130.76,
#   'v_ma20': 231267.29,
#   'turnover': 8.45},
#  {'open': 31.45,
#   'high': 33.2,
#   'close': 33.11,
#   'low': 31.45,
#   'volume': 333824.31,
#   'price_change': 0.7,
#   'p_change': 2.16,
#   'ma5': 30.618,
#   'ma10': 28.489,
#   'ma20': 27.652,
#   'v_ma5': 388894.38,
#   'v_ma10': 282674.4,
#   'v_ma20': 221367.64,
#   'turnover': 8.35},
#  {'open': 29.3,
#   'high': 32.7,
#   'close': 32.41,
#   'low': 28.92,
#   'volume': 501915.41,
#   'price_change': 2.68,
#   'p_change': 9.01,
#   'ma5': 29.662,
#   'ma10': 27.813,
#   'ma20': 27.306,
#   'v_ma5': 404443.54,
#   'v_ma10': 254722.83,
#   'v_ma20': 215395.01,
#   'turnover': 12.56},
#  {'open': 27.86,
#   'high': 30.45,
#   'close': 29.73,
#   'low': 27.54,
#   'volume': 328947.31,
#   'price_change': 1.68,
#   'p_change': 5.99,
#   'ma5': 28.612,
#   'ma10': 27.198,
#   'ma20': 27.072,
#   'v_ma5': 340158.56,
#   'v_ma10': 213120.2,
#   'v_ma20': 208416.55,
#   'turnover': 8.23},
#  {'open': 28.2,
#   'high': 28.75,
#   'close': 28.05,
#   'low': 27.22,
#   'volume': 313290.41,
#   'price_change': -1.74,
#   'p_change': -5.84,
#   'ma5': 27.804,
#   'ma10': 26.856,
#   'ma20': 26.88,
#   'v_ma5': 296239.76,
#   'v_ma10': 193102.21,
#   'v_ma20': 197044.24,
#   'turnover': 7.84},
#  {'open': 29.0,
#   'high': 31.16,
#   'close': 29.79,
#   'low': 28.9,
#   'volume': 466494.47,
#   'price_change': 1.46,
#   'p_change': 5.15,
#   'ma5': 27.28,
#   'ma10': 26.763,
#   'ma20': 26.764,
#   'v_ma5': 247111.56,
#   'v_ma10': 170695.43,
#   'v_ma20': 186873.57,
#   'turnover': 11.68},
#  {'open': 29.2,
#   'high': 29.83,
#   'close': 28.33,
#   'low': 27.85,
#   'volume': 411570.12,
#   'price_change': 1.17,
#   'p_change': 4.31,
#   'ma5': 26.36,
#   'ma10': 26.519,
#   'ma20': 26.572,
#   'v_ma5': 176454.41,
#   'v_ma10': 141111.99,
#   'v_ma20': 171445.99,
#   'turnover': 10.3},
#  {'open': 25.61,
#   'high': 27.2,
#   'close': 27.16,
#   'low': 25.61,
#   'volume': 180490.47,
#   'price_change': 1.47,
#   'p_change': 5.72,
#   'ma5': 25.964,
#   'ma10': 26.465,
#   'ma20': 26.5,
#   'v_ma5': 105002.11,
#   'v_ma10': 115721.45,
#   'v_ma20': 159293.58,
#   'turnover': 4.52},
#  {'open': 25.63,
#   'high': 26.41,
#   'close': 25.69,
#   'low': 25.5,
#   'volume': 109353.35,
#   'price_change': 0.26,
#   'p_change': 1.02,
#   'ma5': 25.784,
#   'ma10': 26.477,
#   'ma20': 26.479,
#   'v_ma5': 86081.84,
#   'v_ma10': 120574.74,
#   'v_ma20': 156028.36,
#   'turnover': 2.74},
#  {'open': 25.3,
#   'high': 25.88,
#   'close': 25.43,
#   'low': 25.23,
#   'volume': 67649.41,
#   'price_change': 0.24,
#   'p_change': 0.95,
#   'ma5': 25.908,
#   'ma10': 26.734,
#   'ma20': 26.542,
#   'v_ma5': 89964.65,
#   'v_ma10': 147619.06,
#   'v_ma20': 159389.25,
#   'turnover': 1.69},
#  {'open': 26.4,
#   'high': 26.48,
#   'close': 25.19,
#   'low': 25.03,
#   'volume': 113208.69,
#   'price_change': -1.16,
#   'p_change': -4.4,
#   'ma5': 26.246,
#   'ma10': 26.843,
#   'ma20': 26.643,
#   'v_ma5': 94279.29,
#   'v_ma10': 157403.83,
#   'v_ma20': 171053.0,
#   'turnover': 2.83},
#  {'open': 26.26,
#   'high': 26.54,
#   'close': 26.35,
#   'low': 26.14,
#   'volume': 54308.65,
#   'price_change': 0.09,
#   'p_change': 0.34,
#   'ma5': 26.678,
#   'ma10': 26.815,
#   'ma20': 26.738,
#   'v_ma5': 105769.58,
#   'v_ma10': 160060.88,
#   'v_ma20': 178294.92,
#   'turnover': 1.36},
#  {'open': 26.28,
#   'high': 26.51,
#   'close': 26.26,
#   'low': 25.92,
#   'volume': 85889.09,
#   'price_change': -0.05,
#   'p_change': -0.19,
#   'ma5': 26.966,
#   'ma10': 26.798,
#   'ma20': 26.767,
#   'v_ma5': 126440.79,
#   'v_ma10': 176067.19,
#   'v_ma20': 192651.51,
#   'turnover': 2.15},
#  {'open': 27.26,
#   'high': 27.37,
#   'close': 26.31,
#   'low': 26.02,
#   'volume': 128767.41,
#   'price_change': -0.81,
#   'p_change': -2.99,
#   'ma5': 27.17,
#   'ma10': 26.945,
#   'ma20': 26.733,
#   'v_ma5': 155067.65,
#   'v_ma10': 203712.91,
#   'v_ma20': 202840.46,
#   'turnover': 3.22},
#  {'open': 27.12,
#   'high': 27.49,
#   'close': 27.12,
#   'low': 26.75,
#   'volume': 89222.62,
#   'price_change': -0.23,
#   'p_change': -0.84,
#   'ma5': 27.56,
#   'ma10': 26.903,
#   'ma20': 26.643,
#   'v_ma5': 205273.46,
#   'v_ma10': 200986.28,
#   'v_ma20': 204488.73,
#   'turnover': 2.23},
#  {'open': 27.8,
#   'high': 28.22,
#   'close': 27.35,
#   'low': 27.0,
#   'volume': 170660.12,
#   'price_change': -0.44,
#   'p_change': -1.58,
#   'ma5': 27.44,
#   'ma10': 26.765,
#   'ma20': 26.484,
#   'v_ma5': 220528.36,
#   'v_ma10': 203051.72,
#   'v_ma20': 206976.96,
#   'turnover': 4.27},
#  {'open': 27.49,
#   'high': 27.88,
#   'close': 27.79,
#   'low': 27.04,
#   'volume': 157664.69,
#   'price_change': 0.51,
#   'p_change': 1.87,
#   'ma5': 26.952,
#   'ma10': 26.625,
#   'ma20': 26.305,
#   'v_ma5': 214352.17,
#   'v_ma10': 201779.99,
#   'v_ma20': 210644.2,
#   'turnover': 3.95},
#  {'open': 27.58,
#   'high': 28.1,
#   'close': 27.28,
#   'low': 27.11,
#   'volume': 229023.39,
#   'price_change': -0.98,
#   'p_change': -3.47,
#   'ma5': 26.63,
#   'ma10': 26.535,
#   'ma20': 26.167,
#   'v_ma5': 225693.6,
#   'v_ma10': 202865.7,
#   'v_ma20': 211476.52,
#   'turnover': 5.73},
#  {'open': 26.52,
#   'high': 29.01,
#   'close': 28.26,
#   'low': 26.52,
#   'volume': 379796.5,
#   'price_change': 1.74,
#   'p_change': 6.56,
#   'ma5': 26.72,
#   'ma10': 26.48,
#   'ma20': 26.084,
#   'v_ma5': 252358.18,
#   'v_ma10': 191481.98,
#   'v_ma20': 212995.67,
#   'turnover': 9.51},
#  {'open': 24.87,
#   'high': 26.66,
#   'close': 26.52,
#   'low': 24.85,
#   'volume': 165497.09,
#   'price_change': 1.61,
#   'p_change': 6.46,
#   'ma5': 26.246,
#   'ma10': 26.349,
#   'ma20': 25.879,
#   'v_ma5': 196699.1,
#   'v_ma10': 171159.43,
#   'v_ma20': 203831.34,
#   'turnover': 4.14},
#  {'open': 25.78,
#   'high': 26.16,
#   'close': 24.91,
#   'low': 24.67,
#   'volume': 139779.2,
#   'price_change': -1.27,
#   'p_change': -4.85,
#   'ma5': 26.09,
#   'ma10': 26.443,
#   'ma20': 25.706,
#   'v_ma5': 185575.07,
#   'v_ma10': 184702.18,
#   'v_ma20': 200104.09,
#   'turnover': 3.5},
#  {'open': 27.0,
#   'high': 27.18,
#   'close': 26.18,
#   'low': 25.87,
#   'volume': 214371.81,
#   'price_change': -1.55,
#   'p_change': -5.59,
#   'ma5': 26.298,
#   'ma10': 26.661,
#   'ma20': 25.635,
#   'v_ma5': 189207.81,
#   'v_ma10': 196528.96,
#   'v_ma20': 199072.47,
#   'turnover': 5.37},
#  {'open': 26.03,
#   'high': 28.48,
#   'close': 27.73,
#   'low': 25.7,
#   'volume': 362346.28,
#   'price_change': 1.84,
#   'p_change': 7.11,
#   'ma5': 26.44,
#   'ma10': 26.736,
#   'ma20': 25.495,
#   'v_ma5': 180037.81,
#   'v_ma10': 209235.84,
#   'v_ma20': 194833.73,
#   'turnover': 9.07},
#  {'open': 25.66,
#   'high': 26.08,
#   'close': 25.89,
#   'low': 25.35,
#   'volume': 101501.12,
#   'price_change': 0.15,
#   'p_change': 0.58,
#   'ma5': 26.24,
#   'ma10': 26.52,
#   'ma20': 25.239,
#   'v_ma5': 130605.78,
#   'v_ma10': 201968.02,
#   'v_ma20': 183411.57,
#   'turnover': 2.54},
#  {'open': 25.95,
#   'high': 26.52,
#   'close': 25.74,
#   'low': 25.53,
#   'volume': 109876.95,
#   'price_change': -0.21,
#   'p_change': -0.81,
#   'ma5': 26.452,
#   'ma10': 26.382,
#   'ma20': 25.098,
#   'v_ma5': 145619.77,
#   'v_ma10': 207991.18,
#   'v_ma20': 191562.46,
#   'turnover': 2.75},
#  {'open': 26.66,
#   'high': 26.66,
#   'close': 25.95,
#   'low': 25.53,
#   'volume': 157942.91,
#   'price_change': -0.94,
#   'p_change': -3.5,
#   'ma5': 26.796,
#   'ma10': 26.203,
#   'ma20': 25.029,
#   'v_ma5': 183829.29,
#   'v_ma10': 210902.21,
#   'v_ma20': 209190.26,
#   'turnover': 3.95},
#  {'open': 26.58,
#   'high': 27.76,
#   'close': 26.89,
#   'low': 26.33,
#   'volume': 168521.77,
#   'price_change': 0.16,
#   'p_change': 0.6,
#   'ma5': 27.024,
#   'ma10': 25.984,
#   'ma20': 24.867,
#   'v_ma5': 203850.1,
#   'v_ma10': 219508.4,
#   'v_ma20': 205704.82,
#   'turnover': 4.22},
#  {'open': 26.7,
#   'high': 27.1,
#   'close': 26.73,
#   'low': 26.42,
#   'volume': 115186.16,
#   'price_change': -0.22,
#   'p_change': -0.82,
#   'ma5': 27.032,
#   'ma10': 25.799,
#   'ma20': 24.642,
#   'v_ma5': 238433.87,
#   'v_ma10': 220087.33,
#   'v_ma20': 204899.57,
#   'turnover': 2.88},
#  {'open': 27.2,
#   'high': 27.85,
#   'close': 26.95,
#   'low': 26.66,
#   'volume': 176571.05,
#   'price_change': -0.51,
#   'p_change': -1.86,
#   'ma5': 26.8,
#   'ma10': 25.688,
#   'ma20': 24.4,
#   'v_ma5': 273330.25,
#   'v_ma10': 234509.37,
#   'v_ma20': 202029.43,
#   'turnover': 4.42},
#  {'open': 27.18,
#   'high': 28.55,
#   'close': 27.46,
#   'low': 26.31,
#   'volume': 300924.56,
#   'price_change': 0.37,
#   'p_change': 1.37,
#   'ma5': 26.312,
#   'ma10': 25.408,
#   'ma20': 24.147,
#   'v_ma5': 270362.6,
#   'v_ma10': 236503.24,
#   'v_ma20': 196693.28,
#   'turnover': 7.53},
#  {'open': 26.9,
#   'high': 27.55,
#   'close': 27.09,
#   'low': 26.56,
#   'volume': 258046.98,
#   'price_change': 0.16,
#   'p_change': 0.59,
#   'ma5': 25.61,
#   'ma10': 24.968,
#   'ma20': 23.846,
#   'v_ma5': 237975.12,
#   'v_ma10': 215506.0,
#   'v_ma20': 183694.65,
#   'turnover': 6.46},
#  {'open': 25.5,
#   'high': 27.47,
#   'close': 26.93,
#   'low': 25.32,
#   'volume': 341440.59,
#   'price_change': 1.36,
#   'p_change': 5.32,
#   'ma5': 24.944,
#   'ma10': 24.609,
#   'ma20': 23.566,
#   'v_ma5': 235166.7,
#   'v_ma10': 201615.98,
#   'v_ma20': 172957.06,
#   'turnover': 8.55},
#  {'open': 24.41,
#   'high': 26.9,
#   'close': 25.57,
#   'low': 24.2,
#   'volume': 289668.06,
#   'price_change': 1.06,
#   'p_change': 4.33,
#   'ma5': 24.566,
#   'ma10': 24.253,
#   'ma20': 23.281,
#   'v_ma5': 201740.8,
#   'v_ma10': 180431.62,
#   'v_ma20': 160218.55,
#   'turnover': 7.25},
#  {'open': 23.51,
#   'high': 24.88,
#   'close': 24.51,
#   'low': 23.38,
#   'volume': 161732.8,
#   'price_change': 0.56,
#   'p_change': 2.34,
#   'ma5': 24.576,
#   'ma10': 23.958,
#   'ma20': 23.105,
#   'v_ma5': 195688.49,
#   'v_ma10': 164855.13,
#   'v_ma20': 150908.43,
#   'turnover': 4.05},
#  {'open': 23.76,
#   'high': 24.32,
#   'close': 23.95,
#   'low': 23.31,
#   'volume': 138987.19,
#   'price_change': 0.19,
#   'p_change': 0.8,
#   'ma5': 24.504,
#   'ma10': 23.814,
#   'ma20': 22.95,
#   'v_ma5': 202643.87,
#   'v_ma10': 175133.74,
#   'v_ma20': 145571.54,
#   'turnover': 3.48},
#  {'open': 24.45,
#   'high': 24.45,
#   'close': 23.76,
#   'low': 23.3,
#   'volume': 244004.84,
#   'price_change': -1.28,
#   'p_change': -5.11,
#   'ma5': 24.326,
#   'ma10': 23.854,
#   'ma20': 22.835,
#   'v_ma5': 193036.87,
#   'v_ma10': 207478.31,
#   'v_ma20': 141090.53,
#   'turnover': 6.11},
#  {'open': 25.33,
#   'high': 25.5,
#   'close': 25.04,
#   'low': 24.78,
#   'volume': 174311.09,
#   'price_change': -0.58,
#   'p_change': -2.26,
#   'ma5': 24.274,
#   'ma10': 23.749,
#   'ma20': 22.732,
#   'v_ma5': 168065.26,
#   'v_ma10': 191901.23,
#   'v_ma20': 130989.34,
#   'turnover': 4.36},
#  {'open': 24.16,
#   'high': 25.88,
#   'close': 25.62,
#   'low': 23.78,
#   'volume': 259406.52,
#   'price_change': 1.47,
#   'p_change': 6.09,
#   'ma5': 23.94,
#   'ma10': 23.485,
#   'ma20': 22.554,
#   'v_ma5': 159122.44,
#   'v_ma10': 189711.82,
#   'v_ma20': 126717.47,
#   'turnover': 6.49},
#  {'open': 23.25,
#   'high': 24.6,
#   'close': 24.15,
#   'low': 23.21,
#   'volume': 196509.73,
#   'price_change': 1.09,
#   'p_change': 4.73,
#   'ma5': 23.34,
#   'ma10': 23.111,
#   'ma20': 22.387,
#   'v_ma5': 134021.77,
#   'v_ma10': 169549.5,
#   'v_ma20': 116718.92,
#   'turnover': 4.92},
#  {'open': 23.45,
#   'high': 23.85,
#   'close': 23.06,
#   'low': 23.04,
#   'volume': 90952.18,
#   'price_change': -0.44,
#   'p_change': -1.87,
#   'ma5': 23.124,
#   'ma10': 22.885,
#   'ma20': 22.274,
#   'v_ma5': 147623.61,
#   'v_ma10': 156883.33,
#   'v_ma20': 110864.84,
#   'turnover': 2.28},
#  {'open': 23.45,
#   'high': 23.7,
#   'close': 23.5,
#   'low': 23.05,
#   'volume': 119146.78,
#   'price_change': 0.13,
#   'p_change': 0.56,
#   'ma5': 23.382,
#   'ma10': 22.723,
#   'ma20': 22.24,
#   'v_ma5': 221919.75,
#   'v_ma10': 151883.31,
#   'v_ma20': 112052.01,
#   'turnover': 2.98},
#  {'open': 22.5,
#   'high': 23.6,
#   'close': 23.37,
#   'low': 22.5,
#   'volume': 129597.0,
#   'price_change': 0.75,
#   'p_change': 3.32,
#   'ma5': 23.224,
#   'ma10': 22.523,
#   'ma20': 22.205,
#   'v_ma5': 215737.21,
#   'v_ma10': 144298.14,
#   'v_ma20': 113275.25,
#   'turnover': 3.24},
#  {'open': 22.87,
#   'high': 23.25,
#   'close': 22.62,
#   'low': 22.47,
#   'volume': 133903.14,
#   'price_change': -0.45,
#   'p_change': -1.95,
#   'ma5': 23.03,
#   'ma10': 22.309,
#   'ma20': 22.187,
#   'v_ma5': 220301.19,
#   'v_ma10': 140005.48,
#   'v_ma20': 111800.14,
#   'turnover': 3.35},
#  {'open': 23.9,
#   'high': 24.06,
#   'close': 23.07,
#   'low': 22.85,
#   'volume': 264518.94,
#   'price_change': -1.28,
#   'p_change': -5.26,
#   'ma5': 22.882,
#   'ma10': 22.252,
#   'ma20': 22.194,
#   'v_ma5': 205077.23,
#   'v_ma10': 136961.73,
#   'v_ma20': 110195.54,
#   'turnover': 6.62},
#  {'open': 22.55,
#   'high': 24.98,
#   'close': 24.35,
#   'low': 22.38,
#   'volume': 462432.88,
#   'price_change': 1.64,
#   'p_change': 7.22,
#   'ma5': 22.646,
#   'ma10': 22.085,
#   'ma20': 22.21,
#   'v_ma5': 166143.05,
#   'v_ma10': 116009.34,
#   'v_ma20': 102483.41,
#   'turnover': 11.57},
#  {'open': 22.6,
#   'high': 22.88,
#   'close': 22.71,
#   'low': 22.14,
#   'volume': 88234.07,
#   'price_change': 0.31,
#   'p_change': 1.38,
#   'ma5': 22.064,
#   'ma10': 21.816,
#   'ma20': 22.178,
#   'v_ma5': 81846.87,
#   'v_ma10': 74702.76,
#   'v_ma20': 87736.24,
#   'turnover': 2.21},
#  {'open': 21.75,
#   'high': 22.98,
#   'close': 22.4,
#   'low': 21.51,
#   'volume': 152416.92,
#   'price_change': 0.52,
#   'p_change': 2.38,
#   'ma5': 21.822,
#   'ma10': 21.714,
#   'ma20': 22.194,
#   'v_ma5': 72859.08,
#   'v_ma10': 70077.44,
#   'v_ma20': 88489.06,
#   'turnover': 3.81},
#  {'open': 21.8,
#   'high': 22.05,
#   'close': 21.88,
#   'low': 21.65,
#   'volume': 57783.36,
#   'price_change': -0.01,
#   'p_change': -0.05,
#   'ma5': 21.588,
#   'ma10': 21.623,
#   'ma20': 22.234,
#   'v_ma5': 59709.77,
#   'v_ma10': 63723.13,
#   'v_ma20': 88923.75,
#   'turnover': 1.45},
#  {'open': 21.37,
#   'high': 22.07,
#   'close': 21.89,
#   'low': 21.35,
#   'volume': 69848.0,
#   'price_change': 0.45,
#   'p_change': 2.1,
#   'ma5': 21.622,
#   'ma10': 21.663,
#   'ma20': 22.273,
#   'v_ma5': 68846.23,
#   'v_ma10': 63888.34,
#   'v_ma20': 91485.69,
#   'turnover': 1.75},
#  {'open': 21.52,
#   'high': 21.68,
#   'close': 21.44,
#   'low': 21.34,
#   'volume': 40952.0,
#   'price_change': -0.06,
#   'p_change': -0.28,
#   'ma5': 21.524,
#   'ma10': 21.663,
#   'ma20': 22.309,
#   'v_ma5': 65875.63,
#   'v_ma10': 64846.36,
#   'v_ma20': 95231.54,
#   'turnover': 1.02},
#  {'open': 21.1,
#   'high': 21.56,
#   'close': 21.5,
#   'low': 20.93,
#   'volume': 43295.1,
#   'price_change': 0.27,
#   'p_change': 1.27,
#   'ma5': 21.568,
#   'ma10': 21.757,
#   'ma20': 22.3,
#   'v_ma5': 67558.65,
#   'v_ma10': 72220.71,
#   'v_ma20': 97943.72,
#   'turnover': 1.08},
#  {'open': 21.85,
#   'high': 22.09,
#   'close': 21.23,
#   'low': 21.1,
#   'volume': 86670.4,
#   'price_change': -0.82,
#   'p_change': -3.72,
#   'ma5': 21.606,
#   'ma10': 21.886,
#   'ma20': 22.274,
#   'v_ma5': 67295.81,
#   'v_ma10': 82252.36,
#   'v_ma20': 104702.04,
#   'turnover': 2.17},
#  {'open': 21.45,
#   'high': 22.2,
#   'close': 22.05,
#   'low': 21.36,
#   'volume': 103465.63,
#   'price_change': 0.65,
#   'p_change': 3.04,
#   'ma5': 21.658,
#   'ma10': 22.064,
#   'ma20': 22.356,
#   'v_ma5': 67736.48,
#   'v_ma10': 83594.8,
#   'v_ma20': 108566.23,
#   'turnover': 2.59},
#  {'open': 21.62,
#   'high': 21.62,
#   'close': 21.4,
#   'low': 21.23,
#   'volume': 54995.01,
#   'price_change': -0.26,
#   'p_change': -1.2,
#   'ma5': 21.704,
#   'ma10': 22.135,
#   'ma20': 22.427,
#   'v_ma5': 58930.45,
#   'v_ma10': 83429.34,
#   'v_ma20': 112174.04,
#   'turnover': 1.38},
#  {'open': 21.62,
#   'high': 21.8,
#   'close': 21.66,
#   'low': 21.49,
#   'volume': 49367.1,
#   'price_change': -0.03,
#   'p_change': -0.14,
#   'ma5': 21.802,
#   'ma10': 22.335,
#   'ma20': 22.547,
#   'v_ma5': 63817.09,
#   'v_ma10': 88957.49,
#   'v_ma20': 122551.57,
#   'turnover': 1.24},
#  {'open': 21.6,
#   'high': 21.97,
#   'close': 21.69,
#   'low': 21.49,
#   'volume': 41980.9,
#   'price_change': 0.2,
#   'p_change': 0.93,
#   'ma5': 21.946,
#   'ma10': 22.539,
#   'ma20': 22.576,
#   'v_ma5': 76882.78,
#   'v_ma10': 100769.73,
#   'v_ma20': 132964.43,
#   'turnover': 1.05},
#  {'open': 22.1,
#   'high': 22.27,
#   'close': 21.49,
#   'low': 21.44,
#   'volume': 88873.78,
#   'price_change': -0.79,
#   'p_change': -3.55,
#   'ma5': 22.166,
#   'ma10': 22.673,
#   'ma20': 22.648,
#   'v_ma5': 97208.92,
#   'v_ma10': 106900.68,
#   'v_ma20': 146038.32,
#   'turnover': 2.22},
#  {'open': 22.18,
#   'high': 22.46,
#   'close': 22.28,
#   'low': 21.99,
#   'volume': 59435.48,
#   'price_change': 0.39,
#   'p_change': 1.78,
#   'ma5': 22.47,
#   'ma10': 22.844,
#   'ma20': 22.639,
#   'v_ma5': 99453.13,
#   'v_ma10': 114124.37,
#   'v_ma20': 147146.25,
#   'turnover': 1.49},
#  {'open': 22.13,
#   'high': 22.49,
#   'close': 21.89,
#   'low': 21.86,
#   'volume': 79428.17,
#   'price_change': -0.49,
#   'p_change': -2.19,
#   'ma5': 22.566,
#   'ma10': 22.883,
#   'ma20': 22.574,
#   'v_ma5': 107928.23,
#   'v_ma10': 119083.05,
#   'v_ma20': 148827.89,
#   'turnover': 1.99},
#  {'open': 22.65,
#   'high': 23.18,
#   'close': 22.38,
#   'low': 22.3,
#   'volume': 114695.56,
#   'price_change': -0.41,
#   'p_change': -1.8,
#   'ma5': 22.868,
#   'ma10': 22.955,
#   'ma20': 22.53,
#   'v_ma5': 114097.89,
#   'v_ma10': 125616.72,
#   'v_ma20': 151033.85,
#   'turnover': 2.87},
#  {'open': 22.78,
#   'high': 22.9,
#   'close': 22.79,
#   'low': 21.84,
#   'volume': 143611.59,
#   'price_change': -0.22,
#   'p_change': -0.96,
#   'ma5': 23.132,
#   'ma10': 22.843,
#   'ma20': 22.45,
#   'v_ma5': 124656.68,
#   'v_ma10': 123666.72,
#   'v_ma20': 154316.35,
#   'turnover': 3.59},
#  {'open': 22.6,
#   'high': 23.36,
#   'close': 23.01,
#   'low': 22.5,
#   'volume': 100094.83,
#   'price_change': 0.25,
#   'p_change': 1.1,
#   'ma5': 23.18,
#   'ma10': 22.661,
#   'ma20': 22.409,
#   'v_ma5': 116592.45,
#   'v_ma10': 127151.72,
#   'v_ma20': 155849.67,
#   'turnover': 2.51},
#  {'open': 23.39,
#   'high': 23.39,
#   'close': 22.76,
#   'low': 22.63,
#   'volume': 101811.01,
#   'price_change': -0.64,
#   'p_change': -2.73,
#   'ma5': 23.218,
#   'ma10': 22.647,
#   'ma20': 22.337,
#   'v_ma5': 128795.61,
#   'v_ma10': 133537.65,
#   'v_ma20': 158236.21,
#   'turnover': 2.55},
#  {'open': 23.53,
#   'high': 23.92,
#   'close': 23.4,
#   'low': 22.85,
#   'volume': 110276.48,
#   'price_change': -0.3,
#   'p_change': -1.27,
#   'ma5': 23.2,
#   'ma10': 22.718,
#   'ma20': 22.286,
#   'v_ma5': 130237.86,
#   'v_ma10': 140918.73,
#   'v_ma20': 160464.67,
#   'turnover': 2.76},
#  {'open': 23.07,
#   'high': 24.2,
#   'close': 23.7,
#   'low': 22.64,
#   'volume': 167489.48,
#   'price_change': 0.67,
#   'p_change': 2.91,
#   'ma5': 23.042,
#   'ma10': 22.759,
#   'ma20': 22.199,
#   'v_ma5': 137135.54,
#   'v_ma10': 156145.65,
#   'v_ma20': 166607.7,
#   'turnover': 4.19},
#  {'open': 22.8,
#   'high': 23.79,
#   'close': 23.03,
#   'low': 22.63,
#   'volume': 103290.47,
#   'price_change': -0.17,
#   'p_change': -0.73,
#   'ma5': 22.554,
#   'ma10': 22.612,
#   'ma20': 22.124,
#   'v_ma5': 122676.77,
#   'v_ma10': 165159.14,
#   'v_ma20': 172661.06,
#   'turnover': 2.59},
#  {'open': 22.75,
#   'high': 23.98,
#   'close': 23.2,
#   'low': 22.75,
#   'volume': 161110.59,
#   'price_change': 0.53,
#   'p_change': 2.34,
#   'ma5': 22.142,
#   'ma10': 22.622,
#   'ma20': 22.136,
#   'v_ma5': 137710.98,
#   'v_ma10': 185175.95,
#   'v_ma20': 181610.12,
#   'turnover': 4.03},
#  {'open': 22.52,
#   'high': 23.1,
#   'close': 22.67,
#   'low': 22.36,
#   'volume': 109022.27,
#   'price_change': 0.06,
#   'p_change': 0.27,
#   'ma5': 22.076,
#   'ma10': 22.433,
#   'ma20': 22.143,
#   'v_ma5': 138279.69,
#   'v_ma10': 180168.13,
#   'v_ma20': 195468.18,
#   'turnover': 2.73},
#  {'open': 21.14,
#   'high': 22.86,
#   'close': 22.61,
#   'low': 20.86,
#   'volume': 144764.88,
#   'price_change': 1.35,
#   'p_change': 6.35,
#   'ma5': 22.236,
#   'ma10': 22.264,
#   'ma20': 22.306,
#   'v_ma5': 151599.61,
#   'v_ma10': 178572.74,
#   'v_ma20': 211100.74,
#   'turnover': 3.62},
#  {'open': 20.63,
#   'high': 21.58,
#   'close': 21.26,
#   'low': 20.63,
#   'volume': 95195.62,
#   'price_change': 0.29,
#   'p_change': 1.38,
#   'ma5': 22.476,
#   'ma10': 22.104,
#   'ma20': 22.354,
#   'v_ma5': 175155.77,
#   'v_ma10': 176450.98,
#   'v_ma20': 214117.38,
#   'turnover': 2.38},
#  {'open': 22.64,
#   'high': 22.66,
#   'close': 20.97,
#   'low': 20.58,
#   'volume': 178461.53,
#   'price_change': -1.9,
#   'p_change': -8.31,
#   'ma5': 22.67,
#   'ma10': 22.056,
#   'ma20': 22.495,
#   'v_ma5': 207641.51,
#   'v_ma10': 184965.98,
#   'v_ma20': 228057.86,
#   'turnover': 4.47},
#  {'open': 23.28,
#   'high': 24.29,
#   'close': 22.87,
#   'low': 22.8,
#   'volume': 163954.17,
#   'price_change': -0.6,
#   'p_change': -2.56,
#   'ma5': 23.102,
#   'ma10': 22.157,
#   'ma20': 22.571,
#   'v_ma5': 232640.92,
#   'v_ma10': 184547.63,
#   'v_ma20': 230585.56,
#   'turnover': 4.1},
#  {'open': 23.6,
#   'high': 23.6,
#   'close': 23.47,
#   'low': 22.81,
#   'volume': 175621.84,
#   'price_change': -0.34,
#   'p_change': -1.43,
#   'ma5': 22.79,
#   'ma10': 22.026,
#   'ma20': 22.468,
#   'v_ma5': 222056.57,
#   'v_ma10': 182934.76,
#   'v_ma20': 228670.24,
#   'turnover': 4.4},
#  {'open': 22.26,
#   'high': 23.95,
#   'close': 23.81,
#   'low': 22.26,
#   'volume': 262545.69,
#   'price_change': 1.58,
#   'p_change': 7.11,
#   'ma5': 22.292,
#   'ma10': 21.853,
#   'ma20': 22.305,
#   'v_ma5': 205545.87,
#   'v_ma10': 180010.6,
#   'v_ma20': 224798.65,
#   'turnover': 6.57},
#  {'open': 22.99,
#   'high': 24.0,
#   'close': 22.23,
#   'low': 21.85,
#   'volume': 257624.34,
#   'price_change': -0.9,
#   'p_change': -3.89,
#   'ma5': 21.732,
#   'ma10': 21.639,
#   'ma20': 22.079,
#   'v_ma5': 177746.19,
#   'v_ma10': 177069.74,
#   'v_ma20': 215196.38,
#   'turnover': 6.45},
#  {'open': 21.11,
#   'high': 23.44,
#   'close': 23.13,
#   'low': 21.06,
#   'volume': 303458.56,
#   'price_change': 1.82,
#   'p_change': 8.54,
#   'ma5': 21.442,
#   'ma10': 21.636,
#   'ma20': 21.924,
#   'v_ma5': 162290.45,
#   'v_ma10': 180162.98,
#   'v_ma20': 205572.5,
#   'turnover': 7.59},
#  {'open': 20.8,
#   'high': 21.44,
#   'close': 21.31,
#   'low': 20.65,
#   'volume': 111032.43,
#   'price_change': 0.33,
#   'p_change': 1.57,
#   'ma5': 21.212,
#   'ma10': 21.649,
#   'ma20': 21.674,
#   'v_ma5': 136454.34,
#   'v_ma10': 178044.29,
#   'v_ma20': 192451.24,
#   'turnover': 2.78},
#  {'open': 20.86,
#   'high': 21.19,
#   'close': 20.98,
#   'low': 20.69,
#   'volume': 93068.35,
#   'price_change': -0.03,
#   'p_change': -0.14,
#   'ma5': 21.262,
#   'ma10': 21.852,
#   'ma20': 21.562,
#   'v_ma5': 143812.95,
#   'v_ma10': 210768.22,
#   'v_ma20': 189283.48,
#   'turnover': 2.33},
#  {'open': 20.59,
#   'high': 21.14,
#   'close': 21.01,
#   'low': 20.51,
#   'volume': 123547.26,
#   'price_change': 0.23,
#   'p_change': 1.11,
#   'ma5': 21.414,
#   'ma10': 22.347,
#   'ma20': 21.463,
#   'v_ma5': 154475.33,
#   'v_ma10': 243628.74,
#   'v_ma20': 186661.35,
#   'turnover': 3.09},
#  {'open': 21.97,
#   'high': 21.99,
#   'close': 20.78,
#   'low': 20.75,
#   'volume': 180345.66,
#   'price_change': -1.2,
#   'p_change': -5.46,
#   'ma5': 21.546,
#   'ma10': 22.603,
#   'ma20': 21.378,
#   'v_ma5': 176393.3,
#   'v_ma10': 251783.78,
#   'v_ma20': 183077.72,
#   'turnover': 4.51},
#  {'open': 21.59,
#   'high': 22.14,
#   'close': 21.98,
#   'low': 21.37,
#   'volume': 174278.0,
#   'price_change': 0.42,
#   'p_change': 1.95,
#   'ma5': 21.83,
#   'ma10': 22.933,
#   'ma20': 21.266,
#   'v_ma5': 198035.52,
#   'v_ma10': 271149.75,
#   'v_ma20': 175424.65,
#   'turnover': 4.36},
#  {'open': 21.6,
#   'high': 21.74,
#   'close': 21.56,
#   'low': 21.13,
#   'volume': 147825.48,
#   'price_change': -0.18,
#   'p_change': -0.83,
#   'ma5': 22.086,
#   'ma10': 22.985,
#   'ma20': 21.102,
#   'v_ma5': 219634.25,
#   'v_ma10': 276623.48,
#   'v_ma20': 169829.99,
#   'turnover': 3.7},
#  {'open': 21.78,
#   'high': 21.94,
#   'close': 21.74,
#   'low': 21.47,
#   'volume': 146380.23,
#   'price_change': 0.07,
#   'p_change': 0.32,
#   'ma5': 22.442,
#   'ma10': 22.909,
#   'ma20': 20.933,
#   'v_ma5': 277723.49,
#   'v_ma10': 274405.71,
#   'v_ma20': 163967.44,
#   'turnover': 3.66},
#  {'open': 22.2,
#   'high': 22.37,
#   'close': 21.67,
#   'low': 21.41,
#   'volume': 233137.12,
#   'price_change': -0.53,
#   'p_change': -2.39,
#   'ma5': 23.28,
#   'ma10': 22.756,
#   'ma20': 20.743,
#   'v_ma5': 332782.16,
#   'v_ma10': 269586.69,
#   'v_ma20': 158480.44,
#   'turnover': 5.83},
#  {'open': 23.1,
#   'high': 23.24,
#   'close': 22.2,
#   'low': 22.06,
#   'volume': 288556.75,
#   'price_change': -1.06,
#   'p_change': -4.56,
#   'ma5': 23.66,
#   'ma10': 22.519,
#   'ma20': 20.555,
#   'v_ma5': 327174.26,
#   'v_ma10': 253323.02,
#   'v_ma20': 148477.09,
#   'turnover': 7.22},
#  {'open': 23.3,
#   'high': 23.87,
#   'close': 23.26,
#   'low': 22.57,
#   'volume': 282271.66,
#   'price_change': -0.08,
#   'p_change': -0.34,
#   'ma5': 24.036,
#   'ma10': 22.211,
#   'ma20': 20.333,
#   'v_ma5': 344263.97,
#   'v_ma10': 230982.02,
#   'v_ma20': 136002.95,
#   'turnover': 7.06},
#  {'open': 24.0,
#   'high': 24.47,
#   'close': 23.34,
#   'low': 23.34,
#   'volume': 438271.69,
#   'price_change': -2.59,
#   'p_change': -9.99,
#   'ma5': 23.884,
#   'ma10': 21.699,
#   'ma20': 20.02,
#   'v_ma5': 333612.72,
#   'v_ma10': 206858.19,
#   'v_ma20': 123274.25,
#   'turnover': 10.97},
#  {'open': 23.32,
#   'high': 25.93,
#   'close': 25.93,
#   'low': 23.26,
#   'volume': 421673.59,
#   'price_change': 2.36,
#   'p_change': 10.01,
#   'ma5': 23.376,
#   'ma10': 21.272,
#   'ma20': 19.694,
#   'v_ma5': 271087.94,
#   'v_ma10': 167798.74,
#   'v_ma20': 103052.22,
#   'turnover': 10.55},
#  {'open': 23.0,
#   'high': 23.84,
#   'close': 23.57,
#   'low': 22.9,
#   'volume': 205097.59,
#   'price_change': -0.51,
#   'p_change': -2.12,
#   'ma5': 22.232,
#   'ma10': 20.579,
#   'ma20': 19.268,
#   'v_ma5': 206391.22,
#   'v_ma10': 129693.95,
#   'v_ma20': 82884.05,
#   'turnover': 5.13},
#  {'open': 23.75,
#   'high': 24.45,
#   'close': 24.08,
#   'low': 22.22,
#   'volume': 374005.34,
#   'price_change': 1.58,
#   'p_change': 7.02,
#   'ma5': 21.378,
#   'ma10': 20.152,
#   'ma20': 18.976,
#   'v_ma5': 179471.78,
#   'v_ma10': 114371.67,
#   'v_ma20': 73335.91,
#   'turnover': 9.36},
#  {'open': 21.0,
#   'high': 22.85,
#   'close': 22.5,
#   'low': 20.94,
#   'volume': 229015.38,
#   'price_change': 1.7,
#   'p_change': 8.17,
#   'ma5': 20.386,
#   'ma10': 19.599,
#   'ma20': 18.665,
#   'v_ma5': 117700.07,
#   'v_ma10': 79699.55,
#   'v_ma20': 55293.91,
#   'turnover': 5.73},
#  {'open': 20.41,
#   'high': 21.78,
#   'close': 20.8,
#   'low': 20.41,
#   'volume': 125647.79,
#   'price_change': 0.59,
#   'p_change': 2.92,
#   'ma5': 19.514,
#   'ma10': 19.218,
#   'ma20': 18.43,
#   'v_ma5': 80103.66,
#   'v_ma10': 63036.5,
#   'v_ma20': 44539.8,
#   'turnover': 3.14},
#  {'open': 19.33,
#   'high': 20.35,
#   'close': 20.21,
#   'low': 19.33,
#   'volume': 98190.0,
#   'price_change': 0.91,
#   'p_change': 4.71,
#   'ma5': 19.168,
#   'ma10': 18.956,
#   'ma20': 18.286,
#   'v_ma5': 64509.53,
#   'v_ma10': 53529.16,
#   'v_ma20': 39407.28,
#   'turnover': 2.46},
#  {'open': 19.31,
#   'high': 19.91,
#   'close': 19.3,
#   'low': 19.11,
#   'volume': 70500.37,
#   'price_change': 0.18,
#   'p_change': 0.94,
#   'ma5': 18.926,
#   'ma10': 18.729,
#   'ma20': 18.161,
#   'v_ma5': 52996.68,
#   'v_ma10': 47374.18,
#   'v_ma20': 35624.83,
#   'turnover': 1.76},
#  {'open': 18.25,
#   'high': 19.35,
#   'close': 19.12,
#   'low': 18.25,
#   'volume': 65146.83,
#   'price_change': 0.98,
#   'p_change': 5.4,
#   'ma5': 18.926,
#   'ma10': 18.59,
#   'ma20': 18.071,
#   'v_ma5': 49271.56,
#   'v_ma10': 43631.15,
#   'v_ma20': 32830.88,
#   'turnover': 1.63},
# ...
#   'v_ma5': 145896.23,
#   'v_ma10': 123169.14,
#   'v_ma20': 107003.53,
#   'turnover': 5.2},
#  {'open': 29.87,
#   'high': 30.99,
#   'close': 29.54,
#   'low': 28.53,
#   'volume': 209382.62,
#   'price_change': 1.32,
#   'p_change': 4.68,
#   'ma5': 25.96,
#   'ma10': 23.679,
#   'ma20': 22.44,
#   'v_ma5': 137509.57,
#   'v_ma10': 115879.26,
#   'v_ma20': 104078.16,
#   'turnover': 7.17},
#  {'open': 27.5,
#   'high': 28.22,
#   'close': 28.22,
#   'low': 26.5,
#   'volume': 121190.11,
#   'price_change': 2.57,
#   'p_change': 10.02,
#   'ma5': 24.508,
#   'ma10': 22.725,
#   'ma20': 22.053,
#   'v_ma5': 117760.48,
#   'v_ma10': 103865.87,
#   'v_ma20': 98766.2,
#   'turnover': 4.15},
#  {'open': 24.1,
#   'high': 25.65,
#   'close': 25.65,
#   'low': 24.1,
#   'volume': 164143.16,
#   'price_change': 2.33,
#   'p_change': 9.99,
#   'ma5': 23.292,
#   'ma10': 21.784,
#   'ma20': 21.733,
#   'v_ma5': 118737.32,
#   'v_ma10': 98652.0,
#   'v_ma20': 99743.64,
#   'turnover': 5.62},
#  {'open': 23.68,
#   'high': 23.69,
#   'close': 23.32,
#   'low': 22.47,
#   'volume': 82945.73,
#   'price_change': 0.25,
#   'p_change': 1.08,
#   'ma5': 22.318,
#   'ma10': 21.166,
#   'ma20': 21.536,
#   'v_ma5': 100396.01,
#   'v_ma10': 90830.02,
#   'v_ma20': 97087.92,
#   'turnover': 2.84},
#  {'open': 22.28,
#   'high': 24.45,
#   'close': 23.07,
#   'low': 22.08,
#   'volume': 109886.22,
#   'price_change': 0.79,
#   'p_change': 3.55,
#   'ma5': 21.896,
#   'ma10': 20.906,
#   'ma20': 21.434,
#   'v_ma5': 100442.05,
#   'v_ma10': 91373.34,
#   'v_ma20': 101965.14,
#   'turnover': 3.76},
#  {'open': 22.35,
#   'high': 22.51,
#   'close': 22.28,
#   'low': 21.57,
#   'volume': 110637.16,
#   'price_change': 0.14,
#   'p_change': 0.63,
#   'ma5': 21.398,
#   'ma10': 20.824,
#   'ma20': 21.383,
#   'v_ma5': 94248.95,
#   'v_ma10': 86211.91,
#   'v_ma20': 106809.49,
#   'turnover': 3.79},
#  {'open': 20.84,
#   'high': 22.59,
#   'close': 22.14,
#   'low': 20.72,
#   'volume': 126074.32,
#   'price_change': 1.36,
#   'p_change': 6.54,
#   'ma5': 20.942,
#   'ma10': 20.845,
#   'ma20': 21.418,
#   'v_ma5': 89971.27,
#   'v_ma10': 84345.72,
#   'v_ma20': 112331.15,
#   'turnover': 4.32},
#  {'open': 21.21,
#   'high': 21.21,
#   'close': 20.78,
#   'low': 20.7,
#   'volume': 72436.6,
#   'price_change': -0.43,
#   'p_change': -2.03,
#   'ma5': 20.276,
#   'ma10': 20.84,
#   'ma20': 21.53,
#   'v_ma5': 78566.68,
#   'v_ma10': 79396.81,
#   'v_ma20': 118543.01,
#   'turnover': 2.48},
#  {'open': 20.78,
#   'high': 21.47,
#   'close': 21.21,
#   'low': 20.4,
#   'volume': 83175.93,
#   'price_change': 0.63,
#   'p_change': 3.06,
#   'ma5': 20.014,
#   'ma10': 20.937,
#   'ma20': 21.653,
#   'v_ma5': 81264.03,
#   'v_ma10': 83223.0,
#   'v_ma20': 122655.85,
#   'turnover': 2.85},
#  {'open': 20.31,
#   'high': 20.84,
#   'close': 20.58,
#   'low': 20.15,
#   'volume': 78920.74,
#   'price_change': 0.58,
#   'p_change': 2.9,
#   'ma5': 19.916,
#   'ma10': 21.108,
#   'ma20': 21.649,
#   'v_ma5': 82304.64,
#   'v_ma10': 90837.92,
#   'v_ma20': 127088.19,
#   'turnover': 2.7},
#  {'open': 19.1,
#   'high': 20.18,
#   'close': 20.0,
#   'low': 19.1,
#   'volume': 89248.75,
#   'price_change': 1.19,
#   'p_change': 6.33,
#   'ma5': 20.25,
#   'ma10': 21.2,
#   'ma20': 21.591,
#   'v_ma5': 78174.86,
#   'v_ma10': 92277.06,
#   'v_ma20': 128790.26,
#   'turnover': 3.05},
#  {'open': 19.56,
#   'high': 19.6,
#   'close': 18.81,
#   'low': 18.59,
#   'volume': 69051.38,
#   'price_change': -0.66,
#   'p_change': -3.39,
#   'ma5': 20.748,
#   'ma10': 21.381,
#   'ma20': 21.572,
#   'v_ma5': 78720.17,
#   'v_ma10': 93666.53,
#   'v_ma20': 133483.77,
#   'turnover': 2.36},
#  {'open': 20.85,
#   'high': 21.0,
#   'close': 19.47,
#   'low': 19.25,
#   'volume': 85923.34,
#   'price_change': -1.25,
#   'p_change': -6.03,
#   'ma5': 21.404,
#   'ma10': 21.682,
#   'ma20': 21.553,
#   'v_ma5': 80226.93,
#   'v_ma10': 100835.28,
#   'v_ma20': 137917.5,
#   'turnover': 2.94},
#  {'open': 22.41,
#   'high': 22.48,
#   'close': 20.72,
#   'low': 20.33,
#   'volume': 88378.98,
#   'price_change': -1.53,
#   'p_change': -6.88,
#   'ma5': 21.86,
#   'ma10': 21.906,
#   'ma20': 21.456,
#   'v_ma5': 85181.97,
#   'v_ma10': 103345.82,
#   'v_ma20': 139744.93,
#   'turnover': 3.03},
#  {'open': 22.2,
#   'high': 22.55,
#   'close': 22.25,
#   'low': 21.83,
#   'volume': 58271.87,
#   'price_change': -0.24,
#   'p_change': -1.07,
#   'ma5': 22.3,
#   'ma10': 21.961,
#   'ma20': 21.253,
#   'v_ma5': 99371.2,
#   'v_ma10': 112556.94,
#   'v_ma20': 139924.12,
#   'turnover': 1.99},
#  {'open': 22.2,
#   'high': 22.8,
#   'close': 22.49,
#   'low': 22.2,
#   'volume': 91975.28,
#   'price_change': 0.4,
#   'p_change': 1.81,
#   'ma5': 22.15,
#   'ma10': 21.942,
#   'ma20': 20.963,
#   'v_ma5': 106379.26,
#   'v_ma10': 127407.07,
#   'v_ma20': 140327.35,
#   'turnover': 3.15},
#  {'open': 21.73,
#   'high': 22.54,
#   'close': 22.09,
#   'low': 21.02,
#   'volume': 76585.19,
#   'price_change': 0.34,
#   'p_change': 1.56,
#   'ma5': 22.014,
#   'ma10': 21.99,
#   'ma20': 20.653,
#   'v_ma5': 108612.9,
#   'v_ma10': 140316.57,
#   'v_ma20': 139159.05,
#   'turnover': 2.62},
#  {'open': 22.93,
#   'high': 23.1,
#   'close': 21.75,
#   'low': 21.47,
#   'volume': 110698.53,
#   'price_change': -1.17,
#   'p_change': -5.11,
#   'ma5': 21.96,
#   'ma10': 22.219,
#   'ma20': 20.357,
#   'v_ma5': 121443.63,
#   'v_ma10': 157689.21,
#   'v_ma20': 139553.18,
#   'turnover': 3.79},
#  {'open': 22.56,
#   'high': 23.65,
#   'close': 22.92,
#   'low': 22.56,
#   'volume': 159325.12,
#   'price_change': 1.42,
#   'p_change': 6.61,
#   'ma5': 21.952,
#   'ma10': 22.368,
#   'ma20': 20.09,
#   'v_ma5': 121509.68,
#   'v_ma10': 162088.7,
#   'v_ma20': 138272.77,
#   'turnover': 5.45},
#  {'open': 21.82,
#   'high': 21.82,
#   'close': 21.5,
#   'low': 21.0,
#   'volume': 93312.18,
#   'price_change': -0.31,
#   'p_change': -1.42,
#   'ma5': 21.622,
#   'ma10': 22.189,
#   'ma20': 19.733,
#   'v_ma5': 125742.68,
#   'v_ma10': 163338.46,
#   'v_ma20': 136324.12,
#   'turnover': 3.19},
#  {'open': 22.0,
#   'high': 22.4,
#   'close': 21.81,
#   'low': 21.72,
#   'volume': 103143.46,
#   'price_change': -0.01,
#   'p_change': -0.05,
#   'ma5': 21.734,
#   'ma10': 21.982,
#   'ma20': 19.404,
#   'v_ma5': 148434.88,
#   'v_ma10': 165303.46,
#   'v_ma20': 135902.4,
#   'turnover': 3.53},
#  {'open': 21.9,
#   'high': 22.3,
#   'close': 21.82,
#   'low': 21.58,
#   'volume': 140738.84,
#   'price_change': 0.11,
#   'p_change': 0.51,
#   'ma5': 21.966,
#   'ma10': 21.763,
#   'ma20': 19.079,
#   'v_ma5': 172020.25,
#   'v_ma10': 173301.02,
#   'v_ma20': 135603.95,
#   'turnover': 4.82},
#  {'open': 21.0,
#   'high': 21.97,
#   'close': 21.71,
#   'low': 20.8,
#   'volume': 111028.8,
#   'price_change': 0.44,
#   'p_change': 2.07,
#   'ma5': 22.478,
#   'ma10': 21.423,
#   'ma20': 18.772,
#   'v_ma5': 193934.8,
#   'v_ma10': 174999.73,
#   'v_ma20': 136236.51,
#   'turnover': 3.8},
#  {'open': 21.7,
#   'high': 22.78,
#   'close': 21.27,
#   'low': 20.24,
#   'volume': 180490.12,
#   'price_change': -0.79,
#   'p_change': -3.58,
#   'ma5': 22.784,
#   'ma10': 21.006,
#   'ma20': 18.455,
#   'v_ma5': 202667.73,
#   'v_ma10': 176144.03,
#   'v_ma20': 135158.14,
#   'turnover': 6.18},
#  {'open': 22.6,
#   'high': 23.97,
#   'close': 22.06,
#   'low': 21.8,
#   'volume': 206773.17,
#   'price_change': -0.91,
#   'p_change': -3.96,
#   'ma5': 22.756,
#   'ma10': 20.545,
#   'ma20': 18.159,
#   'v_ma5': 200934.24,
#   'v_ma10': 167291.31,
#   'v_ma20': 129973.64,
#   'turnover': 7.08},
#  {'open': 24.63,
#   'high': 25.21,
#   'close': 22.97,
#   'low': 21.94,
#   'volume': 221070.31,
#   'price_change': -1.41,
#   'p_change': -5.78,
#   'ma5': 22.23,
#   'ma10': 19.983,
#   'ma20': 17.825,
#   'v_ma5': 182172.04,
#   'v_ma10': 153247.63,
#   'v_ma20': 124317.19,
#   'turnover': 7.57},
#  {'open': 23.45,
#   'high': 25.56,
#   'close': 24.38,
#   'low': 23.4,
#   'volume': 250311.59,
#   'price_change': 1.14,
#   'p_change': 4.91,
#   'ma5': 21.56,
#   'ma10': 19.315,
#   'ma20': 17.442,
#   'v_ma5': 174581.78,
#   'v_ma10': 138001.54,
#   'v_ma20': 119340.61,
#   'turnover': 8.57},
#  {'open': 21.45,
#   'high': 23.24,
#   'close': 23.24,
#   'low': 21.45,
#   'volume': 154693.44,
#   'price_change': 2.11,
#   'p_change': 9.99,
#   'ma5': 20.368,
#   'ma10': 18.494,
#   'ma20': 16.982,
#   'v_ma5': 156064.66,
#   'v_ma10': 121417.14,
#   'v_ma20': 114763.57,
#   'turnover': 5.3},
#  {'open': 19.6,
#   'high': 21.3,
#   'close': 21.13,
#   'low': 19.5,
#   'volume': 171822.69,
#   'price_change': 1.7,
#   'p_change': 8.75,
#   'ma5': 19.228,
#   'ma10': 17.812,
#   'ma20': 16.563,
#   'v_ma5': 149620.34,
#   'v_ma10': 114456.84,
#   'v_ma20': 111752.31,
#   'turnover': 5.88},
#  {'open': 19.55,
#   'high': 19.89,
#   'close': 19.43,
#   'low': 19.2,
#   'volume': 112962.15,
#   'price_change': -0.19,
#   'p_change': -0.97,
#   'ma5': 18.334,
#   'ma10': 17.276,
#   'ma20': 16.23,
#   'v_ma5': 133648.38,
#   'v_ma10': 109309.78,
#   'v_ma20': 106228.29,
#   'turnover': 3.87},
#  {'open': 18.28,
#   'high': 19.89,
#   'close': 19.62,
#   'low': 18.02,
#   'volume': 183119.05,
#   'price_change': 1.2,
#   'p_change': 6.51,
#   'ma5': 17.736,
#   'ma10': 16.826,
#   'ma20': 15.964,
#   'v_ma5': 124323.21,
#   'v_ma10': 106501.34,
#   'v_ma20': 104829.1,
#   'turnover': 6.27},
#  {'open': 17.6,
#   'high': 18.53,
#   'close': 18.42,
#   'low': 17.6,
#   'volume': 157725.97,
#   'price_change': 0.88,
#   'p_change': 5.02,
#   'ma5': 17.07,
#   'ma10': 16.394,
#   'ma20': 15.698,
#   'v_ma5': 101421.29,
#   'v_ma10': 97906.88,
#   'v_ma20': 101658.57,
#   'turnover': 5.4},
#  {'open': 16.54,
#   'high': 17.98,
#   'close': 17.54,
#   'low': 16.5,
#   'volume': 122471.85,
#   'price_change': 0.88,
#   'p_change': 5.28,
#   'ma5': 16.62,
#   'ma10': 16.12,
#   'ma20': 15.51,
#   'v_ma5': 86769.62,
#   'v_ma10': 97473.29,
#   'v_ma20': 98832.94,
#   'turnover': 4.19},
#  {'open': 16.44,
#   'high': 16.77,
#   'close': 16.66,
#   'low': 16.25,
#   'volume': 91962.88,
#   'price_change': 0.22,
#   'p_change': 1.34,
#   'ma5': 16.396,
#   'ma10': 15.904,
#   'ma20': 15.348,
#   'v_ma5': 79293.34,
#   'v_ma10': 94172.24,
#   'v_ma20': 99956.63,
#   'turnover': 3.15},
#  {'open': 16.21,
#   'high': 16.5,
#   'close': 16.44,
#   'low': 16.21,
#   'volume': 66336.32,
#   'price_change': 0.15,
#   'p_change': 0.92,
#   'ma5': 16.218,
#   'ma10': 15.772,
#   'ma20': 15.229,
#   'v_ma5': 84971.19,
#   'v_ma10': 92655.96,
#   'v_ma20': 104350.08,
#   'turnover': 2.27},
#  {'open': 16.18,
#   'high': 16.48,
#   'close': 16.29,
#   'low': 16.0,
#   'volume': 68609.42,
#   'price_change': 0.12,
#   'p_change': 0.74,
#   'ma5': 15.916,
#   'ma10': 15.666,
#   'ma20': 15.065,
#   'v_ma5': 88679.47,
#   'v_ma10': 95386.75,
#   'v_ma20': 105692.28,
#   'turnover': 2.35},
#  {'open': 16.78,
#   'high': 16.88,
#   'close': 16.17,
#   'low': 16.07,
#   'volume': 84467.62,
#   'price_change': -0.25,
#   'p_change': -1.52,
#   'ma5': 15.718,
#   'ma10': 15.568,
#   'ma20': 14.896,
#   'v_ma5': 94392.47,
#   'v_ma10': 100679.68,
#   'v_ma20': 105615.58,
#   'turnover': 2.89},
#  {'open': 15.99,
#   'high': 16.63,
#   'close': 16.42,
#   'low': 15.99,
#   'volume': 85090.45,
#   'price_change': 0.65,
#   'p_change': 4.12,
#   'ma5': 15.62,
#   'ma10': 15.469,
#   'ma20': 14.722,
#   'v_ma5': 108176.96,
#   'v_ma10': 108109.99,
#   'v_ma20': 108345.78,
#   'turnover': 2.91},
#  {'open': 14.9,
#   'high': 15.86,
#   'close': 15.77,
#   'low': 14.9,
#   'volume': 120352.13,
#   'price_change': 0.84,
#   'p_change': 5.63,
#   'ma5': 15.412,
#   'ma10': 15.314,
#   'ma20': 14.527,
#   'v_ma5': 109051.14,
#   'v_ma10': 109047.78,
#   'v_ma20': 108905.84,
#   'turnover': 4.12},
#  {'open': 15.14,
#   'high': 15.35,
#   'close': 14.93,
#   'low': 14.91,
#   'volume': 84877.75,
#   'price_change': -0.37,
#   'p_change': -2.42,
#   'ma5': 15.326,
#   'ma10': 15.184,
#   'ma20': 14.462,
#   'v_ma5': 100340.74,
#   'v_ma10': 103146.79,
#   'v_ma20': 108303.41,
#   'turnover': 2.91},
#  {'open': 15.97,
#   'high': 15.97,
#   'close': 15.3,
#   'low': 15.18,
#   'volume': 97174.4,
#   'price_change': -0.38,
#   'p_change': -2.42,
#   'ma5': 15.416,
#   'ma10': 15.102,
#   'ma20': 14.436,
#   'v_ma5': 102094.02,
#   'v_ma10': 103156.85,
#   'v_ma20': 109604.83,
#   'turnover': 3.33},
#  {'open': 15.38,
#   'high': 16.16,
#   'close': 15.68,
#   'low': 15.28,
#   'volume': 153390.08,
#   'price_change': 0.3,
#   'p_change': 1.95,
#   'ma5': 15.418,
#   'ma10': 15.002,
#   'ma20': 14.385,
#   'v_ma5': 106966.89,
#   'v_ma10': 105410.25,
#   'v_ma20': 110336.03,
#   'turnover': 5.25},
#  {'open': 15.34,
#   'high': 15.56,
#   'close': 15.38,
#   'low': 15.25,
#   'volume': 89461.32,
#   'price_change': 0.04,
#   'p_change': 0.26,
#   'ma5': 15.318,
#   'ma10': 14.899,
#   'ma20': 14.304,
#   'v_ma5': 108043.02,
#   'v_ma10': 100192.6,
#   'v_ma20': 107645.16,
#   'turnover': 3.06},
#  {'open': 15.38,
#   'high': 15.48,
#   'close': 15.34,
#   'low': 15.18,
#   'volume': 76800.13,
#   'price_change': -0.04,
#   'p_change': -0.26,
#   'ma5': 15.216,
#   'ma10': 14.792,
#   'ma20': 14.232,
#   'v_ma5': 109044.42,
#   'v_ma10': 105741.03,
#   'v_ma20': 108857.41,
#   'turnover': 2.63},
#  {'open': 15.2,
#   'high': 15.64,
#   'close': 15.38,
#   'low': 15.11,
#   'volume': 93644.19,
#   'price_change': 0.07,
#   'p_change': 0.46,
#   'ma5': 15.042,
#   'ma10': 14.686,
#   'ma20': 14.153,
#   'v_ma5': 105952.84,
#   'v_ma10': 116044.19,
#   'v_ma20': 111147.22,
#   'turnover': 3.21},
#  {'open': 15.18,
#   'high': 15.66,
#   'close': 15.31,
#   'low': 15.02,
#   'volume': 121538.71,
#   'price_change': 0.13,
#   'p_change': 0.86,
#   'ma5': 14.788,
#   'ma10': 14.464,
#   'ma20': 14.058,
#   'v_ma5': 104219.67,
#   'v_ma10': 115997.81,
#   'v_ma20': 112493.6,
#   'turnover': 4.16},
#  {'open': 14.9,
#   'high': 15.44,
#   'close': 15.18,
#   'low': 14.63,
#   'volume': 158770.77,
#   'price_change': 0.31,
#   'p_change': 2.08,
#   'ma5': 14.586,
#   'ma10': 14.223,
#   'ma20': 13.954,
#   'v_ma5': 103853.62,
#   'v_ma10': 110551.48,
#   'v_ma20': 111739.85,
#   'turnover': 5.43},
#  {'open': 14.52,
#   'high': 15.05,
#   'close': 14.87,
#   'low': 14.51,
#   'volume': 94468.3,
#   'price_change': 0.4,
#   'p_change': 2.76,
#   'ma5': 14.48,
#   'ma10': 13.975,
#   'ma20': 13.843,
#   'v_ma5': 92342.17,
#   'v_ma10': 108581.56,
#   'v_ma20': 107464.31,
#   'turnover': 3.23},
#  {'open': 14.13,
#   'high': 14.5,
#   'close': 14.47,
#   'low': 14.08,
#   'volume': 61342.22,
#   'price_change': 0.36,
#   'p_change': 2.55,
#   'ma5': 14.368,
#   'ma10': 13.74,
#   'ma20': 13.74,
#   'v_ma5': 102437.64,
#   'v_ma10': 108763.91,
#   'v_ma20': 108763.91,
#   'turnover': 2.1},
#  {'open': 14.11,
#   'high': 14.8,
#   'close': 14.11,
#   'low': 13.95,
#   'volume': 84978.37,
#   'price_change': -0.19,
#   'p_change': -1.33,
#   'ma5': 14.33,
#   'ma10': 13.659,
#   'ma20': 13.659,
#   'v_ma5': 126135.54,
#   'v_ma10': 114032.98,
#   'v_ma20': 114032.98,
#   'turnover': 2.91},
#  {'open': 14.8,
#   'high': 15.08,
#   'close': 14.3,
#   'low': 14.14,
#   'volume': 119708.43,
#   'price_change': -0.35,
#   'p_change': -2.39,
#   'ma5': 14.14,
#   'ma10': 13.603,
#   'ma20': 13.603,
#   'v_ma5': 127775.94,
#   'v_ma10': 117664.81,
#   'v_ma20': 117664.81,
#   'turnover': 4.1},
#  {'open': 14.2,
#   'high': 14.8,
#   'close': 14.65,
#   'low': 14.01,
#   'volume': 101213.51,
#   'price_change': 0.34,
#   'p_change': 2.38,
#   'ma5': 13.86,
#   'ma10': 13.503,
#   'ma20': 13.503,
#   'v_ma5': 117249.34,
#   'v_ma10': 117372.87,
#   'v_ma20': 117372.87,
#   'turnover': 3.46},
#  {'open': 14.14,
#   'high': 14.85,
#   'close': 14.31,
#   'low': 13.8,
#   'volume': 144945.66,
#   'price_change': 0.03,
#   'p_change': 0.21,
#   'ma5': 13.47,
#   'ma10': 13.312,
#   'ma20': 13.312,
#   'v_ma5': 124820.96,
#   'v_ma10': 120066.09,
#   'v_ma20': 120066.09,
#   'turnover': 4.96},
#  {'open': 13.17,
#   'high': 14.48,
#   'close': 14.28,
#   'low': 13.13,
#   'volume': 179831.72,
#   'price_change': 1.12,
#   'p_change': 8.51,
#   'ma5': 13.112,
#   'ma10': 13.112,
#   'ma20': 13.112,
#   'v_ma5': 115090.18,
#   'v_ma10': 115090.18,
#   'v_ma20': 115090.18,
#   'turnover': 6.16},
#  {'open': 12.88,
#   'high': 13.45,
#   'close': 13.16,
#   'low': 12.87,
#   'volume': 93180.39,
#   'price_change': 0.26,
#   'p_change': 2.02,
#   'ma5': 12.82,
#   'ma10': 12.82,
#   'ma20': 12.82,
#   'v_ma5': 98904.79,
#   'v_ma10': 98904.79,
#   'v_ma20': 98904.79,
#   'turnover': 3.19},
#  {'open': 12.8,
#   'high': 12.92,
#   'close': 12.9,
#   'low': 12.61,
#   'volume': 67075.44,
#   'price_change': 0.2,
#   'p_change': 1.57,
#   'ma5': 12.707,
#   'ma10': 12.707,
#   'ma20': 12.707,
#   'v_ma5': 100812.93,
#   'v_ma10': 100812.93,
#   'v_ma20': 100812.93,
#   'turnover': 2.3},
#  {'open': 12.52,
#   'high': 13.06,
#   'close': 12.7,
#   'low': 12.52,
#   'volume': 139071.61,
#   'price_change': 0.18,
#   'p_change': 1.44,
#   'ma5': 12.61,
#   'ma10': 12.61,
#   'ma20': 12.61,
#   'v_ma5': 117681.67,
#   'v_ma10': 117681.67,
#   'v_ma20': 117681.67,
#   'turnover': 4.76},
#  {'open': 12.25,
#   'high': 12.67,
#   'close': 12.52,
#   'low': 12.2,
#   'volume': 96291.73,
#   'price_change': 0.32,
#   'p_change': 2.62,
#   'ma5': 12.52,
#   'ma10': 12.52,
#   'ma20': 12.52,
#   'v_ma5': 96291.73,
#   'v_ma10': 96291.73,
#   'v_ma20': 96291.73,
#   'turnover': 3.3}]

# %% [markdown]
# ## to_json(orient="records")

# %%
data.to_json(orient="records")
# Out:
# '[{"open":23.53,"high":25.88,"close":24.16,"low":23.53,"volume":95578.03,"price_change":0.63,"p_change":2.68,"ma5":22.942,"ma10":22.142,"ma20":22.875,"v_ma5":53782.64,"v_ma10":46738.65,"v_ma20":55576.11,"turnover":2.39},{"open":22.8,"high":23.78,"close":23.53,"low":22.8,"volume":60985.11,"price_change":0.69,"p_change":3.02,"ma5":22.406,"ma10":21.955,"ma20":22.942,"v_ma5":40827.52,"v_ma10":42736.34,"v_ma20":56007.5,"turnover":1.53},{"open":22.88,"high":23.37,"close":22.82,"low":22.71,"volume":52914.01,"price_change":0.54,"p_change":2.42,"ma5":21.938,"ma10":21.929,"ma20":23.022,"v_ma5":35119.58,"v_ma10":41871.97,"v_ma20":56372.85,"turnover":1.32},{"open":22.25,"high":22.76,"close":22.28,"low":22.02,"volume":36105.01,"price_change":0.36,"p_change":1.64,"ma5":21.446,"ma10":21.909,"ma20":23.137,"v_ma5":35397.58,"v_ma10":39904.78,"v_ma20":60149.6,"turnover":0.9},{"open":21.49,"high":21.99,"close":21.92,"low":21.48,"volume":23331.04,"price_change":0.44,"p_change":2.05,"ma5":21.366,"ma10":21.923,"ma20":23.253,"v_ma5":33590.21,"v_ma10":42935.74,"v_ma20":61716.11,"turnover":0.58},{"open":21.4,"high":21.9,"close":21.48,"low":21.31,"volume":30802.45,"price_change":0.28,"p_change":1.32,"ma5":21.342,"ma10":22.103,"ma20":23.387,"v_ma5":39694.65,"v_ma10":45518.14,"v_ma20":65161.68,"turnover":0.77},{"open":20.7,"high":21.4,"close":21.19,"low":20.63,"volume":32445.39,"price_change":0.82,"p_change":4.03,"ma5":21.504,"ma10":22.338,"ma20":23.533,"v_ma5":44645.16,"v_ma10":45679.94,"v_ma20":68686.33,"turnover":0.81},{"open":21.2,"high":21.46,"close":20.36,"low":20.19,"volume":54304.01,"price_change":-1.5,"p_change":-6.86,"ma5":21.92,"ma10":22.596,"ma20":23.645,"v_ma5":48624.36,"v_ma10":48982.38,"v_ma20":70552.47,"turnover":1.36},{"open":21.79,"high":22.09,"close":21.88,"low":21.75,"volume":27068.16,"price_change":0.09,"p_change":0.41,"ma5":22.372,"ma10":23.009,"ma20":23.839,"v_ma5":44411.98,"v_ma10":48612.16,"v_ma20":73852.45,"turnover":0.68},{"open":22.69,"high":23.11,"close":21.8,"low":21.29,"volume":53853.25,"price_change":-0.5,"p_change":-2.24,"ma5":22.48,"ma10":23.258,"ma20":23.929,"v_ma5":52281.28,"v_ma10":56315.11,"v_ma20":74925.33,"turnover":1.35},{"open":22.8,"high":23.55,"close":22.29,"low":22.2,"volume":55555.0,"price_change":-0.97,"p_change":-4.17,"ma5":22.864,"ma10":23.607,"ma20":24.029,"v_ma5":51341.63,"v_ma10":64413.58,"v_ma20":75738.95,"turnover":1.39},{"open":22.45,"high":23.39,"close":23.27,"low":22.25,"volume":52341.39,"price_change":0.65,"p_change":2.87,"ma5":23.172,"ma10":23.928,"ma20":24.112,"v_ma5":46714.72,"v_ma10":69278.66,"v_ma20":77070.0,"turnover":1.31},{"open":22.4,"high":22.7,"close":22.62,"low":21.53,"volume":33242.11,"price_change":0.2,"p_change":0.89,"ma5":23.272,"ma10":24.114,"ma20":24.184,"v_ma5":49340.4,"v_ma10":70873.73,"v_ma20":79929.71,"turnover":0.83},{"open":23.71,"high":23.86,"close":22.42,"low":22.22,"volume":66414.64,"price_change":-1.3,"p_change":-5.48,"ma5":23.646,"ma10":24.365,"ma20":24.279,"v_ma5":52812.35,"v_ma10":80394.43,"v_ma20":88480.92,"turnover":1.66},{"open":23.85,"high":23.98,"close":23.72,"low":23.31,"volume":49155.02,"price_change":-0.11,"p_change":-0.46,"ma5":24.036,"ma10":24.583,"ma20":24.411,"v_ma5":60348.94,"v_ma10":80496.48,"v_ma20":91666.75,"turnover":1.23},{"open":23.71,"high":24.08,"close":23.83,"low":23.7,"volume":32420.43,"price_change":0.05,"p_change":0.21,"ma5":24.35,"ma10":24.671,"ma20":24.365,"v_ma5":77485.53,"v_ma10":84805.23,"v_ma20":92943.35,"turnover":0.81},{"open":24.4,"high":24.63,"close":23.77,"low":23.72,"volume":65469.81,"price_change":-0.73,"p_change":-2.98,"ma5":24.684,"ma10":24.728,"ma20":24.294,"v_ma5":91842.6,"v_ma10":91692.73,"v_ma20":93456.22,"turnover":1.64},{"open":24.27,"high":24.74,"close":24.49,"low":24.22,"volume":50601.83,"price_change":0.11,"p_change":0.45,"ma5":24.956,"ma10":24.694,"ma20":24.221,"v_ma5":92407.05,"v_ma10":92122.56,"v_ma20":91980.51,"turnover":1.27},{"open":24.99,"high":24.99,"close":24.37,"low":24.23,"volume":104097.59,"price_change":-0. ...
