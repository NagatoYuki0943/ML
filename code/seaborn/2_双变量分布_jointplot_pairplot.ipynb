# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Seaborn----绘制统计图形

# %% [markdown]
# ## 绘制双变量分布 jointplot
# seaborn.jointplot(x, y, data=None,
#                   kind='scatter', stat_func=None, color=None,
#                   ratio=5, space=0.2, dropna=True)
# - x, y:  数据中的列名
# - data: 数据
# - (1) kind：表示绘制图形的类型。
#     - scatter:  散点图
#     - kde:        等高线
#     - hex:        六边形图
# - (2) stat_func：用于计算有关关系的统计量并标注图。
# - (3) color：表示绘图元素的颜色。
# - (4) height：用于设置图的大小(正方形)。
# - (5) ratio：表示中心图与侧边图的比例。该参数的值越大，则中心图的占比会越大。
# - (6) space：用于设置中心图与侧边图的间隔大小。

# %% [markdown]
# ### 绘制散点图 scatter

# %%
# 通过字典创建DataFrame
df = pd.DataFrame({"x":np.random.randn(500), "y":np.random.randn(500), "z":np.random.randn(500)})
df.head()
# Out:
#           x         y         z
# 0 -0.994456 -0.004750 -0.023980
# 1  0.070365 -1.671226 -0.158786
# 2 -0.878596 -0.893041 -1.084262
# 3 -0.926419 -0.060522  0.017683
# 4 -1.413925  0.057719  1.461496

# %%
# 绘制散布图
sns.jointplot(data=df, x='x', y='y')

# %%
# 绘制散布图
sns.jointplot(data=df, x='x', y='y', hue="z")

# %%
# kind：默认散点图
sns.jointplot(data=df, x='x', y='y', kind='scatter')

# %%
# kind：默认散点图
sns.jointplot(data=df, x='x', y='y', hue="z", kind='scatter')

# %% [markdown]
# ### 绘制二维直方图 hex

# %%
# 六边形图
sns.jointplot(data=df, x='x', y='y', kind='hex')

# %% [markdown]
# ### 绘制核密度估计图形 kde

# %%
# 等高线
sns.jointplot(data=df, x='x', y='y', kind='kde')

# %% [markdown]
# ### 其他参数

# %%
# stat_func：用于计算有关关系的统计量并标注图。
# color：表示绘图元素的颜色。
# size：用于设置图的大小(正方形)。
# ratio：表示中心图与侧边图的比例。该参数的值越大，则中心图的占比会越大。
# space：用于设置中心图与侧边图的间隔大小。
sns.jointplot(x='x', y='y', data= df, color='red', height=6, ratio=5, space=1)

# %% [markdown]
# ## 绘制成对的双变量分布(多变量) pairplot

# %%
# 加载seaborn中的数据集
dataset = sns.load_dataset("iris")
dataset[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 绘制多个成对的双变量分布
sns.pairplot(dataset)
