# %%
import numpy as np
import pandas as pd
import json
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # load

# %%
result_path = Path("./results/camera_result.jsonl")
result_path.exists()
# Out:
# True

# %%
results = []
with open(result_path, mode='r', encoding='utf-8') as f:
    for line in f:
        result = json.loads(line)
        results.append(result)
results[0]
# Out:
# {'timestamp': 'image--20240911-145558.481330--1',
#  'threshold': 10.192287086291408,
#  'center_xs': [251.67640055804623,
#   251.64963666617436,
#   251.616690147067,
#   251.60061820856066,
#   251.51593836452162,
#   251.44053393734376],
#  'center_ys': [251.4083886747877,
#   251.3416399892383,
#   251.3350130250401,
#   251.14834571096173,
#   251.11006149985027,
#   250.90758189672633],
#  'radii': [47.39296607429729,
#   84.73547050837468,
#   122.98370728154177,
#   160.32646859212235,
#   198.5296350668858,
#   235.87686180000168],
#  'err_avgs': [-0.001774705605634355,
#   -0.0017164990508574324,
#   -0.0025657844807959614,
#   -0.003416289637109741,
#   -0.004416412419356373,
#   -0.004883600598181588],
#  'err_vars': [0.168213975529001,
#   0.2908937630248297,
#   0.6310927918682219,
#   1.095431635352395,
#   1.7535579871297955,
#   2.303832917234388],
#  'err_stds': [0.41013897099519936,
#   0.5393456804544092,
#   0.7944134892285137,
#   1.0466286998512868,
# ...

# %% [markdown]
# # 0

# %%
_0_thresholds = [result['threshold'] for result in results if '--0' in result['timestamp']]
_0_center_xss = [result['center_xs'] for result in results if '--0' in result['timestamp']]
_0_center_yss = [result['center_ys'] for result in results if '--0' in result['timestamp']]
_0_center_xs = [result['center_x_mean'] for result in results if '--0' in result['timestamp']]
_0_center_ys = [result['center_y_mean'] for result in results if '--0' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_thresholds)
plt.grid()
plt.title("0_threshold")
# Out:
# Text(0.5, 1.0, '0_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_center_xs)
plt.grid()
plt.title("0_center_x")
# Out:
# Text(0.5, 1.0, '0_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_center_ys)
plt.grid()
plt.title("0_center_y")
# Out:
# Text(0.5, 1.0, '0_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(_0_center_xs,_0_center_ys, marker='.')
plt.grid()
plt.title("0_center")
# Out:
# Text(0.5, 1.0, '0_center')

# %% [markdown]
# # 1

# %%
_1_thresholds = [result['threshold'] for result in results if '--1' in result['timestamp']]
_1_center_xss = [result['center_xs'] for result in results if '--1' in result['timestamp']]
_1_center_yss = [result['center_ys'] for result in results if '--1' in result['timestamp']]
_1_center_xs = [result['center_x_mean'] for result in results if '--1' in result['timestamp']]
_1_center_ys = [result['center_y_mean'] for result in results if '--1' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_thresholds)
plt.grid()
plt.title("1_threshold")
# Out:
# Text(0.5, 1.0, '1_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_center_xs)
plt.grid()
plt.title("1_center_x")
# Out:
# Text(0.5, 1.0, '1_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_center_ys)
plt.grid()
plt.title("1_center_y")
# Out:
# Text(0.5, 1.0, '1_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(_1_center_xs,_1_center_ys, marker='.')
plt.grid()
plt.title("1_center")
# Out:
# Text(0.5, 1.0, '1_center')

# %% [markdown]
# # 2

# %%
_2_thresholds = [result['threshold'] for result in results if '--2' in result['timestamp']]
_2_center_xss = [result['center_xs'] for result in results if '--2' in result['timestamp']]
_2_center_yss = [result['center_ys'] for result in results if '--2' in result['timestamp']]
_2_center_xs = [result['center_x_mean'] for result in results if '--2' in result['timestamp']]
_2_center_ys = [result['center_y_mean'] for result in results if '--2' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(_2_thresholds)
plt.grid()
plt.title("2_threshold")
# Out:
# Text(0.5, 1.0, '2_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_2_center_xs)
plt.grid()
plt.title("2_center_x")
# Out:
# Text(0.5, 1.0, '2_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_2_center_ys)
plt.grid()
plt.title("2_center_y")
# Out:
# Text(0.5, 1.0, '2_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(_2_center_xs,_2_center_ys, marker='.')
plt.grid()
plt.title("2_center")
# Out:
# Text(0.5, 1.0, '2_center')
