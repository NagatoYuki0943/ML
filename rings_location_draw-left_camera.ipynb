# %%
import numpy as np
import pandas as pd
import json
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # load

# %%
result_path = Path("./results/left_result.jsonl")
result_path.exists()
# Out:
# True

# %%
results = []
with open(result_path, mode='r', encoding='utf-8') as f:
    for line in f:
        result = json.loads(line)
        results.append(result)
results[0]
# Out:
# {'timestamp': 'left_image--20240829-164721.426827--up',
#  'threshold': 15.655162245670649,
#  'center_xs': [159.23992499545218,
#   159.25848172897386,
#   159.2333624572387,
#   159.2347422007722,
#   159.18986252097082,
#   159.16710011544134],
#  'center_ys': [159.25585814374142,
#   159.2244176638058,
#   159.22644222812596,
#   159.17705490123132,
#   159.14187126213744,
#   159.07050127420123],
#  'radii': [30.57470361240365,
#   54.80750447703105,
#   79.34115721510196,
#   103.5924610310802,
#   128.12439120429815,
#   152.39035104811828],
#  'err_avgs': [-0.00013581896815012472,
#   -0.00020858999747898157,
#   -0.00028520741707973126,
#   -0.0003492037122773864,
#   -0.0004498794951491713,
#   -0.0005130976123421727],
#  'err_vars': [0.008305230932527255,
#   0.022864550934634374,
#   0.04525729169429334,
#   0.0723496219694503,
#   0.11528087046387933,
#   0.15638198727319494],
#  'err_stds': [0.09113303974150788,
#   0.15121028713230583,
#   0.2127376123168946,
#   0.2689788504129094,
#   0.3395303675135397,
#   0.39545162444121396],
#  'center_x_mean': 159.22057900314152,
#  'center_y_mean': 159.1826909122072,
#  'metadata': {'SensorTimestamp': 173432260423000,
#   'ExposureTime': 118800,
#   'FocusFoM': 1205,
#   'AnalogueGain': 7.876923084259033,
#   'AeLocked': True,
#   'ColourCorrectionMatrix': [2.1730945110321045,
#    -0.9661786556243896,
#    -0.20691196620464325,
#    -0.3726436495780945,
#    2.0591437816619873,
#    -0.6864940524101257,
#    -0.13334044814109802,
#    -0.44095295667648315,
#    1.5742933750152588],
#   'SensorBlackLevels': [4096, 4096, 4096, 4096],
#   'FrameDuration': 119428,
#   'Lux': 4.312867164611816,
#   'ColourTemperature': 5374,
#   'SensorTemperature': 80.0,
#   'DigitalGain': 1.000235676765442,
#   'ColourGains': [3.205379009246826, 1.4416676759719849],
#   'ScalerCrop': [0, 0, 4056, 3040]}}

# %% [markdown]
# # up

# %%
up_thresholds = [result['threshold'] for result in results if 'up' in result['timestamp']]
up_center_xss = [result['center_xs'] for result in results if 'up' in result['timestamp']]
up_center_yss = [result['center_ys'] for result in results if 'up' in result['timestamp']]
up_center_xs = [result['center_x_mean'] for result in results if 'up' in result['timestamp']]
up_center_ys = [result['center_y_mean'] for result in results if 'up' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(up_thresholds)
plt.grid()
plt.title("up_threshold")
# Out:
# Text(0.5, 1.0, 'up_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(up_center_xs)
plt.grid()
plt.title("up_center_x")
# Out:
# Text(0.5, 1.0, 'up_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(up_center_ys)
plt.grid()
plt.title("up_center_y")
# Out:
# Text(0.5, 1.0, 'up_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(up_center_xs,up_center_ys, marker='.')
plt.grid()
plt.title("up_center")
# Out:
# Text(0.5, 1.0, 'up_center')

# %% [markdown]
# # down

# %%
down_thresholds = [result['threshold'] for result in results if 'down' in result['timestamp']]
down_center_xss = [result['center_xs'] for result in results if 'down' in result['timestamp']]
down_center_yss = [result['center_ys'] for result in results if 'down' in result['timestamp']]
down_center_xs = [result['center_x_mean'] for result in results if 'down' in result['timestamp']]
down_center_ys = [result['center_y_mean'] for result in results if 'down' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(down_thresholds)
plt.grid()
plt.title("up_threshold")
# Out:
# Text(0.5, 1.0, 'up_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(down_center_xs)
plt.grid()
plt.title("down_center_x")
# Out:
# Text(0.5, 1.0, 'down_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(down_center_ys)
plt.grid()
plt.title("down_center_y")
# Out:
# Text(0.5, 1.0, 'down_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(down_center_xs,down_center_ys, marker='.')
plt.grid()
plt.title("down_center")
# Out:
# Text(0.5, 1.0, 'down_center')
