# %%
import numpy as np
import pandas as pd
import json
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # load

# %%
result_path = Path("./results/camera_result.jsonl")
result_path.exists()
# Out:
# True

# %%
results = []
with open(result_path, mode='r', encoding='utf-8') as f:
    for line in f:
        result = json.loads(line)
        results.append(result)
results[0]
# Out:
# {'timestamp': 'image--20240909-084838.155776--0',
#  'threshold': 12.104547150901393,
#  'center_xs': [159.52736509929204,
#   159.57509073188692,
#   159.5135616504581,
#   159.50064682161906,
#   159.50967697779737,
#   159.49942885564423],
#  'center_ys': [159.69974917698596,
#   159.68314985505535,
#   159.6301022774063,
#   159.60415663465716,
#   159.56304999350613,
#   159.50542042893724],
#  'radii': [30.5991979218313,
#   54.8261383869471,
#   79.44409220209249,
#   103.68609697093615,
#   128.266755960798,
#   152.52017342785845],
#  'err_avgs': [-0.0002447432629815198,
#   -0.00025004317237888984,
#   -0.00025095029462700937,
#   -0.0003305815569650814,
#   -0.00047074634430897247,
#   -0.0005209496587419927],
#  'err_vars': [0.014977835167102759,
#   0.027417740619276754,
#   0.03987297372021192,
#   0.06855331346287301,
#   0.12076199133605664,
#   0.15891039320048922],
#  'err_stds': [0.12238396613569426,
#   0.16558303240150168,
#   0.19968218177947655,
#   0.2618268768917221,
#   0.34750826081700076,
#   0.39863566473722495],
#  'center_x_mean': 159.52096168944965,
#  'center_y_mean': 159.6142713944247,
#  'metadata': {'SensorTimestamp': 175438965504000,
#   'ExposureTime': 98000,
#   'FocusFoM': 800,
#   'AnalogueGain': 7.876923084259033,
#   'AeLocked': True,
#   'ColourCorrectionMatrix': [2.1800098419189453,
#    -0.9601159691810608,
#    -0.21989241242408752,
#    -0.36966219544410706,
#    2.026183605194092,
#    -0.6565130352973938,
#    -0.14505676925182343,
#    -0.4038337171077728,
#    1.548890471458435],
#   'SensorBlackLevels': [4096, 4096, 4096, 4096],
#   'FrameDuration': 100000,
#   'Lux': 4.378285884857178,
#   'ColourTemperature': 5675,
#   'SensorTemperature': 80.0,
#   'DigitalGain': 1.0038011074066162,
#   'ColourGains': [3.2581560611724854, 1.4244203567504883],
#   'ScalerCrop': [0, 0, 4056, 3040]}}

# %% [markdown]
# # 0

# %%
_0_thresholds = [result['threshold'] for result in results if '--0' in result['timestamp']]
_0_center_xss = [result['center_xs'] for result in results if '--0' in result['timestamp']]
_0_center_yss = [result['center_ys'] for result in results if '--0' in result['timestamp']]
_0_center_xs = [result['center_x_mean'] for result in results if '--0' in result['timestamp']]
_0_center_ys = [result['center_y_mean'] for result in results if '--0' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_thresholds)
plt.grid()
plt.title("0_threshold")
# Out:
# Text(0.5, 1.0, '0_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_center_xs)
plt.grid()
plt.title("0_center_x")
# Out:
# Text(0.5, 1.0, '0_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_center_ys)
plt.grid()
plt.title("0_center_y")
# Out:
# Text(0.5, 1.0, '0_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(_0_center_xs,_0_center_ys, marker='.')
plt.grid()
plt.title("0_center")
# Out:
# Text(0.5, 1.0, '0_center')

# %% [markdown]
# # down

# %%
_1_thresholds = [result['threshold'] for result in results if '--1' in result['timestamp']]
_1_center_xss = [result['center_xs'] for result in results if '--1' in result['timestamp']]
_1_center_yss = [result['center_ys'] for result in results if '--1' in result['timestamp']]
_1_center_xs = [result['center_x_mean'] for result in results if '--1' in result['timestamp']]
_1_center_ys = [result['center_y_mean'] for result in results if '--1' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_thresholds)
plt.grid()
plt.title("1_threshold")
# Out:
# Text(0.5, 1.0, '1_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_center_xs)
plt.grid()
plt.title("1_center_x")
# Out:
# Text(0.5, 1.0, '1_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_center_ys)
plt.grid()
plt.title("1_center_y")
# Out:
# Text(0.5, 1.0, '1_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(_1_center_xs,_1_center_ys, marker='.')
plt.grid()
plt.title("1_center")
# Out:
# Text(0.5, 1.0, '1_center')
