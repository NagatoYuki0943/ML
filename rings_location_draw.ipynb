# %%
import numpy as np
import pandas as pd
import json
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # load

# %%
result_path = Path("./results/camera_result.jsonl")
result_path.exists()
# Out:
# True

# %%
results = []
with open(result_path, mode='r', encoding='utf-8') as f:
    for line in f:
        result = json.loads(line)
        results.append(result)
results[0]
# Out:
# {'timestamp': 'image--20240905-164954.608794--0',
#  'threshold': 12.187640470858724,
#  'center_xs': [251.1802714610024,
#   251.04785145605518,
#   251.3443065347419,
#   251.19072609328137,
#   251.3176616291189,
#   251.13760643995212],
#  'center_ys': [251.71088788663772,
#   251.79633752241938,
#   251.69526455950722,
#   251.62396870290593,
#   251.4166836061721,
#   251.2034610506724],
#  'radii': [48.81737171788849,
#   85.5985295138399,
#   125.69306162802182,
#   162.46322259144063,
#   202.49574508048659,
#   239.3151799864663],
#  'err_avgs': [-0.008882417315717029,
#   -0.007533382923312032,
#   -0.004398318317753281,
#   -0.006142694893905053,
#   -0.00321491673362983,
#   -0.00602569454692059],
#  'err_vars': [0.8671536383671783,
#   1.2896362491319697,
#   1.1056568455218525,
#   1.9958862830619475,
#   1.3020035830194667,
#   2.8840440410921295],
#  'err_stds': [0.9312108452800463,
#   1.1356215254793165,
#   1.0515021852197228,
#   1.4127583951482814,
#   1.141053716097304,
#   1.698247343908457],
#  'center_x_mean': 251.20307060235862,
#  'center_y_mean': 251.57443388805245,
#  'metadata': {'SensorTimestamp': 12670529040000,
#   'ExposureTime': 74000,
#   'FocusFoM': 1326,
#   'AnalogueGain': 8.0,
#   'AeLocked': True,
#   'ColourCorrectionMatrix': [2.168699026107788,
#    -0.9700319766998291,
#    -0.19866175949573517,
#    -0.3745386004447937,
#    2.0800929069519043,
#    -0.7055495381355286,
#    -0.1258937269449234,
#    -0.46454545855522156,
#    1.5904392004013062],
#   'SensorBlackLevels': [4096, 4096, 4096, 4096],
#   'FrameDuration': 100000,
#   'Lux': 7.7952399253845215,
#   'ColourTemperature': 5183,
#   'SensorTemperature': 80.0,
#   'DigitalGain': 1.023306131362915,
#   'ColourGains': [3.172715902328491, 1.45284903049469],
#   'ScalerCrop': [0, 0, 4056, 3040]}}

# %% [markdown]
# # 0

# %%
_0_thresholds = [result['threshold'] for result in results if '--0' in result['timestamp']]
_0_center_xss = [result['center_xs'] for result in results if '--0' in result['timestamp']]
_0_center_yss = [result['center_ys'] for result in results if '--0' in result['timestamp']]
_0_center_xs = [result['center_x_mean'] for result in results if '--0' in result['timestamp']]
_0_center_ys = [result['center_y_mean'] for result in results if '--0' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_thresholds)
plt.grid()
plt.title("0_threshold")
# Out:
# Text(0.5, 1.0, '0_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_center_xs)
plt.grid()
plt.title("0_center_x")
# Out:
# Text(0.5, 1.0, '0_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_center_ys)
plt.grid()
plt.title("0_center_y")
# Out:
# Text(0.5, 1.0, '0_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(_0_center_xs,_0_center_ys, marker='.')
plt.grid()
plt.title("0_center")
# Out:
# Text(0.5, 1.0, '0_center')

# %% [markdown]
# # down

# %%
_1_thresholds = [result['threshold'] for result in results if '--1' in result['timestamp']]
_1_center_xss = [result['center_xs'] for result in results if '--1' in result['timestamp']]
_1_center_yss = [result['center_ys'] for result in results if '--1' in result['timestamp']]
_1_center_xs = [result['center_x_mean'] for result in results if '--1' in result['timestamp']]
_1_center_ys = [result['center_y_mean'] for result in results if '--1' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_thresholds)
plt.grid()
plt.title("1_threshold")
# Out:
# Text(0.5, 1.0, '1_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_center_xs)
plt.grid()
plt.title("1_center_x")
# Out:
# Text(0.5, 1.0, '1_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_center_ys)
plt.grid()
plt.title("1_center_y")
# Out:
# Text(0.5, 1.0, '1_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(_1_center_xs,_1_center_ys, marker='.')
plt.grid()
plt.title("1_center")
# Out:
# Text(0.5, 1.0, '1_center')
