# %%
import numpy as np
import pandas as pd
import json
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # load

# %%
result_path = Path("./results/camera_result.jsonl")
result_path.exists()
# Out:
# True

# %%
results = []
with open(result_path, mode='r', encoding='utf-8') as f:
    for line in f:
        result = json.loads(line)
        results.append(result)
results[0]
# Out:
# {'timestamp': 'image--20240906-120504.567056--0',
#  'threshold': 6.037945852974904,
#  'center_xs': [250.8335240863355,
#   250.8332669929989,
#   250.77915624283494,
#   250.92199619432935,
#   250.91637353601797,
#   251.00227659737038],
#  'center_ys': [251.12384609908227,
#   250.91802884649584,
#   251.0264611594639,
#   250.7967034542193,
#   250.69927660376365,
#   250.53841763072901],
#  'radii': [48.424271403355874,
#   85.26400579253834,
#   124.92387470498029,
#   161.73181076602316,
#   201.34925001417102,
#   238.16125132014787],
#  'err_avgs': [-0.0007077446174592745,
#   -0.0011689306749635953,
#   -0.0012896257057763414,
#   -0.0019659087692435883,
#   -0.002199128718787709,
#   -0.0027790354102333143],
#  'err_vars': [0.06854353398316262,
#   0.19933405727139455,
#   0.32220841705561626,
#   0.6358961052955194,
#   0.8855810002657771,
#   1.3237093785141207],
#  'err_stds': [0.26180820075613104,
#   0.4464684280790687,
#   0.567634052057852,
#   0.7974309407688664,
#   0.9410531336039305,
#   1.1505256965900938],
#  'center_x_mean': 250.88109894164782,
#  'center_y_mean': 250.85045563229232,
#  'metadata': {'SensorTimestamp': 10103105151000,
#   'ExposureTime': 74000,
#   'FocusFoM': 1413,
#   'AnalogueGain': 8.0,
#   'AeLocked': True,
#   'ColourCorrectionMatrix': [1.9748594760894775,
#    -0.7156795263290405,
#    -0.2591899633407593,
#    -0.43473267555236816,
#    2.0987930297851562,
#    -0.6640604138374329,
#    -0.04917403683066368,
#    -0.8441071510314941,
#    1.8932812213897705],
#   'SensorBlackLevels': [4096, 4096, 4096, 4096],
#   'FrameDuration': 100000,
#   'Lux': 14.448277473449707,
#   'ColourTemperature': 2445,
#   'SensorTemperature': 80.0,
#   'DigitalGain': 1.0151342153549194,
#   'ColourGains': [2.1123898029327393, 3.8502354621887207],
#   'ScalerCrop': [0, 0, 4056, 3040]}}

# %% [markdown]
# # 0

# %%
_0_thresholds = [result['threshold'] for result in results if '--0' in result['timestamp']]
_0_center_xss = [result['center_xs'] for result in results if '--0' in result['timestamp']]
_0_center_yss = [result['center_ys'] for result in results if '--0' in result['timestamp']]
_0_center_xs = [result['center_x_mean'] for result in results if '--0' in result['timestamp']]
_0_center_ys = [result['center_y_mean'] for result in results if '--0' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_thresholds)
plt.grid()
plt.title("0_threshold")
# Out:
# Text(0.5, 1.0, '0_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_center_xs)
plt.grid()
plt.title("0_center_x")
# Out:
# Text(0.5, 1.0, '0_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_0_center_ys)
plt.grid()
plt.title("0_center_y")
# Out:
# Text(0.5, 1.0, '0_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(_0_center_xs,_0_center_ys, marker='.')
plt.grid()
plt.title("0_center")
# Out:
# Text(0.5, 1.0, '0_center')

# %% [markdown]
# # down

# %%
_1_thresholds = [result['threshold'] for result in results if '--1' in result['timestamp']]
_1_center_xss = [result['center_xs'] for result in results if '--1' in result['timestamp']]
_1_center_yss = [result['center_ys'] for result in results if '--1' in result['timestamp']]
_1_center_xs = [result['center_x_mean'] for result in results if '--1' in result['timestamp']]
_1_center_ys = [result['center_y_mean'] for result in results if '--1' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_thresholds)
plt.grid()
plt.title("1_threshold")
# Out:
# Text(0.5, 1.0, '1_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_center_xs)
plt.grid()
plt.title("1_center_x")
# Out:
# Text(0.5, 1.0, '1_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(_1_center_ys)
plt.grid()
plt.title("1_center_y")
# Out:
# Text(0.5, 1.0, '1_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(_1_center_xs,_1_center_ys, marker='.')
plt.grid()
plt.title("1_center")
# Out:
# Text(0.5, 1.0, '1_center')
