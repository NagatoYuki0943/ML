# %%
import numpy as np
import pandas as pd
import json
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # load

# %%
result_path = Path("./results/camera1_result.jsonl")
result_path.exists()
# Out:
# True

# %%
results = []
with open(result_path, mode='r', encoding='utf-8') as f:
    for line in f:
        result = json.loads(line)
        results.append(result)
results[0]
# Out:
# {'timestamp': 'camera1--20240829-143152.410381--up',
#  'threshold': 16.112188661283422,
#  'center_xs': [159.50440520502246,
#   159.49908707789365,
#   159.4952023605963,
#   159.47285370987066,
#   159.44748814137577,
#   159.41546367776942],
#  'center_ys': [159.28448712721703,
#   159.2647262081364,
#   159.25155145891358,
#   159.21639490639308,
#   159.17528912646736,
#   159.10305668960595],
#  'radii': [30.55719839966585,
#   54.78901240773999,
#   79.32968812833043,
#   103.58727486465224,
#   128.11323372517901,
#   152.37148250990305],
#  'err_avgs': [-0.00012132951806844368,
#   -0.00019422594749179828,
#   -0.0002829696361119944,
#   -0.0003556510492652244,
#   -0.0004214718422321648,
#   -0.0005194660216167656],
#  'err_vars': [0.007414965586087914,
#   0.021282857959657654,
#   0.04489570590580415,
#   0.07368171949668663,
#   0.10799206365208092,
#   0.15830334581185646],
#  'err_stds': [0.08611019443763854,
#   0.1458864557101092,
#   0.2118860682201738,
#   0.27144376857221575,
#   0.3286214595124319,
#   0.3978735299210749],
#  'center_x_mean': 159.47241669542134,
#  'center_y_mean': 159.21591758612223,
#  'metadata': {'SensorTimestamp': 165303233688000,
#   'ExposureTime': 110885,
#   'FocusFoM': 1178,
#   'AnalogueGain': 7.876923084259033,
#   'AeLocked': True,
#   'ColourCorrectionMatrix': [2.1700727939605713,
#    -0.9688276052474976,
#    -0.2012404054403305,
#    -0.37394630908966064,
#    2.073545217514038,
#    -0.6995936632156372,
#    -0.12822124361991882,
#    -0.4571714997291565,
#    1.585392713546753],
#   'SensorBlackLevels': [4096, 4096, 4096, 4096],
#   'FrameDuration': 111514,
#   'Lux': 4.566563129425049,
#   'ColourTemperature': 5243,
#   'SensorTemperature': 80.0,
#   'DigitalGain': 1.0048496723175049,
#   'ColourGains': [3.1828536987304688, 1.4493358135223389],
#   'ScalerCrop': [0, 0, 4056, 3040]}}

# %% [markdown]
# # up

# %%
up_thresholds = [result['threshold'] for result in results if 'up' in result['timestamp']]
up_center_xss = [result['center_xs'] for result in results if 'up' in result['timestamp']]
up_center_yss = [result['center_ys'] for result in results if 'up' in result['timestamp']]
up_center_xs = [result['center_x_mean'] for result in results if 'up' in result['timestamp']]
up_center_ys = [result['center_y_mean'] for result in results if 'up' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(up_thresholds)
plt.grid()
plt.title("up_threshold")
# Out:
# Text(0.5, 1.0, 'up_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(up_center_xs)
plt.grid()
plt.title("up_center_x")
# Out:
# Text(0.5, 1.0, 'up_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(up_center_ys)
plt.grid()
plt.title("up_center_y")
# Out:
# Text(0.5, 1.0, 'up_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(up_center_xs,up_center_ys, marker='.')
plt.grid()
plt.title("up_center")
# Out:
# Text(0.5, 1.0, 'up_center')

# %% [markdown]
# # down

# %%
down_thresholds = [result['threshold'] for result in results if 'down' in result['timestamp']]
down_center_xss = [result['center_xs'] for result in results if 'down' in result['timestamp']]
down_center_yss = [result['center_ys'] for result in results if 'down' in result['timestamp']]
down_center_xs = [result['center_x_mean'] for result in results if 'down' in result['timestamp']]
down_center_ys = [result['center_y_mean'] for result in results if 'down' in result['timestamp']]

# %%
plt.figure(figsize=(20, 8))
plt.plot(down_thresholds)
plt.grid()
plt.title("up_threshold")
# Out:
# Text(0.5, 1.0, 'up_threshold')

# %%
plt.figure(figsize=(20, 8))
plt.plot(down_center_xs)
plt.grid()
plt.title("down_center_x")
# Out:
# Text(0.5, 1.0, 'down_center_x')

# %%
plt.figure(figsize=(20, 8))
plt.plot(down_center_ys)
plt.grid()
plt.title("down_center_y")
# Out:
# Text(0.5, 1.0, 'down_center_y')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(down_center_xs,down_center_ys, marker='.')
plt.grid()
plt.title("down_center")
# Out:
# Text(0.5, 1.0, 'down_center')
